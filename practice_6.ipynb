# %% [markdown]
# # Practice 6
# - More LeetCode Questions

# %% [markdown]
# # Questions 1001-1050

# %%
from typing import List

# %% [markdown]
# ## 1001. Maximum Strong Pair XOR I
#
# - You are given a 0-indexed integer array nums. A pair of integers x and y is called a strong pair if it satisfies the condition:
#
#     - |x - y| <= min(x, y)
#
# - You need to select two integers from nums such that they form a strong pair and their bitwise XOR is the maximum among all strong pairs in the array.
#
# - Return the maximum XOR value out of all possible strong pairs in the array nums.
#
# - Note that you can pick the same integer twice to form a pair.
#
#
#
# - Example 1:
#     - Input: nums = [1,2,3,4,5]
#     - Output: 7
#     - Explanation: There are 11 strong pairs in the array nums: (1, 1), (1, 2), (2, 2), (2, 3), (2, 4), (3, 3), (3, 4), (3, 5), (4, 4), (4, 5) and (5, 5).
# The maximum XOR possible from these pairs is 3 XOR 4 = 7.
#
# - Example 2:
#     - Input: nums = [10,100]
#     - Output: 0
#     - Explanation: There are 2 strong pairs in the array nums: (10, 10) and (100, 100).
# The maximum XOR possible from these pairs is 10 XOR 10 = 0 since the pair (100, 100) also gives 100 XOR 100 = 0.
#
# - Example 3:
#     - Input: nums = [5,6,25,30]
#     - Output: 7
#     - Explanation: There are 6 strong pairs in the array nums: (5, 5), (5, 6), (6, 6), (25, 25), (25, 30) and (30, 30).
# The maximum XOR possible from these pairs is 25 XOR 30 = 7 since the only other non-zero XOR value is 5 XOR 6 = 3.
#
#
# - Constraints:
#     - 1 <= nums.length <= 50
#     - 1 <= nums[i] <= 100
#
# - Hint 1
#     - The constraints are small enough to make brute-force solutions pass.

# %%
# simulation, brute force, tried all combinations
# time complexity: O(n^2)
# space complexity: O(n^2) for pairs
class Solution:
    def maximumStrongPairXor(self, nums: List[int]) -> int:
        pairs = []
        n = len(nums)
        for x in nums:
            for y in nums:
                if abs(x - y) <= min(x, y):
                    pairs.append((x, y))
        result = float("-inf")
        for x, y in pairs:
            result = max(result, x ^ y)

        return result
    
# use a MAX XOR binary Trie, could also use for part 2 of this problem
# time complexity: O(n log M), n = len of array, M is maximum value of array
# space complexity: O(n log M)
class BinaryTrie:
    def __init__(self, bit_length=32):
        self.root = {"count": 0}
        self.bit_length = bit_length

    def _get_bits(self, number):
        bits = []
        for i in range(self.bit_length - 1, -1, -1):
            bits.append((number >> i) & 1)
        return bits

    def insert(self, number):
        current = self.root
        bits = self._get_bits(number)

        current["count"] += 1

        for bit in bits:
            if bit not in current:
                current[bit] = {"count": 0}
            current = current[bit]
            current["count"] += 1

    def search(self, number: int) -> bool:
        current = self.root
        bits = self._get_bits(number)

        for bit in bits:
            if bit not in current or current[bit]["count"] == 0:
                return False
            current = current[bit]
        return True

    def find_max_xor(self, x: int) -> int:
        current = self.root
        max_xor_result = 0

        for i in range(self.bit_length - 1, -1, -1):
            bit_x = (x >> i) & 1
            ideal_bit = 1 - bit_x

            if ideal_bit in current:
                max_xor_result |= (1 << i)
                current = current[ideal_bit]
            else:
                current = current[bit_x]

        return max_xor_result

    def remove(self, number):
        if not self.search(number):
            return

        current = self.root
        bits = self._get_bits(number)

        current["count"] -= 1

        for bit in bits:
            parent = current
            current = current[bit]
            current["count"] -= 1

            if current["count"] == 0:
                del parent[bit]
                break


class Solution:
    def maximumStrongPairXor(self, nums: List[int]) -> int:
        nums.sort()
        tree = BinaryTrie(20)
        result = i = 0
        for y in nums:
            tree.insert(y)
            while y > nums[i] * 2:
                tree.remove(nums[i])
                i += 1
            result = max(result, tree.find_max_xor(y))
        return result

# %% [markdown]
# ## 1002. Maximum Strong Pair XOR II
#
# - You are given a 0-indexed integer array nums. A pair of integers x and y is called a strong pair if it satisfies the condition:
#
#     - |x - y| <= min(x, y)
#
# - You need to select two integers from nums such that they form a strong pair and their bitwise XOR is the maximum among all strong pairs in the array.
#
# - Return the maximum XOR value out of all possible strong pairs in the array nums.
#
# - Note that you can pick the same integer twice to form a pair.
#
#
#
# - Example 1:
#     - Input: nums = [1,2,3,4,5]
#     - Output: 7
#     - Explanation: There are 11 strong pairs in the array nums: (1, 1), (1, 2), (2, 2), (2, 3), (2, 4), (3, 3), (3, 4), (3, 5), (4, 4), (4, 5) and (5, 5).
# The maximum XOR possible from these pairs is 3 XOR 4 = 7.
#
# - Example 2:
#     - Input: nums = [10,100]
#     - Output: 0
#     - Explanation: There are 2 strong pairs in the array nums: (10, 10) and (100, 100).
# The maximum XOR possible from these pairs is 10 XOR 10 = 0 since the pair (100, 100) also gives 100 XOR 100 = 0.
#
# - Example 3:
#     - Input: nums = [500,520,2500,3000]
#     - Output: 1020
#     - Explanation: There are 6 strong pairs in the array nums: (500, 500), (500, 520), (520, 520), (2500, 2500), (2500, 3000) and (3000, 3000).
# The maximum XOR possible from these pairs is 500 XOR 520 = 1020 since the only other non-zero XOR value is 2500 XOR 3000 = 636.
#
#
# - Constraints:
#     - 1 <= nums.length <= 5 * 10^4
#     - 1 <= nums[i] <= 2^20 - 1
#
# - Hint 1
#     - Sort the array, now let x <= y which means |x - y| <= min(x, y) can now be written as y - x <= x or in other words, y <= 2 * x.
# - Hint 2
#     - If x and y have the same number of bits, try makingy’s bits different from x if possible for each bit starting from the second most significant bit.
# - Hint 3
#     - If y has 1 more bit than x and y <= 2 * x use the idea about Digit DP to make y’s prefix smaller than 2 * x + 1 as well as trying to make each bit different from x using a Hashmap.
# - Hint 4
#     - Alternatively, use Trie data structure to find the pair with maximum XOR.

# %%
# use a MAX XOR binary Trie, could also use for part 2 of this problem
# time complexity: O(n log M), n = len of array, M is maximum value of array
# space complexity: O(n log M)
class BinaryTrie:
    def __init__(self, bit_length=32):
        self.root = {"count": 0}
        self.bit_length = bit_length

    def _get_bits(self, number):
        bits = []
        for i in range(self.bit_length - 1, -1, -1):
            bits.append((number >> i) & 1)
        return bits

    def insert(self, number):
        current = self.root
        bits = self._get_bits(number)

        current["count"] += 1

        for bit in bits:
            if bit not in current:
                current[bit] = {"count": 0}
            current = current[bit]
            current["count"] += 1

    def search(self, number: int) -> bool:
        current = self.root
        bits = self._get_bits(number)

        for bit in bits:
            if bit not in current or current[bit]["count"] == 0:
                return False
            current = current[bit]
        return True

    def find_max_xor(self, x: int) -> int:
        current = self.root
        max_xor_result = 0

        for i in range(self.bit_length - 1, -1, -1):
            bit_x = (x >> i) & 1
            ideal_bit = 1 - bit_x

            if ideal_bit in current:
                max_xor_result |= (1 << i)
                current = current[ideal_bit]
            else:
                current = current[bit_x]

        return max_xor_result

    def remove(self, number):
        if not self.search(number):
            return

        current = self.root
        bits = self._get_bits(number)

        current["count"] -= 1

        for bit in bits:
            parent = current
            current = current[bit]
            current["count"] -= 1

            if current["count"] == 0:
                del parent[bit]
                break


class Solution:
    def maximumStrongPairXor(self, nums: List[int]) -> int:
        nums.sort()
        tree = BinaryTrie(20)
        result = i = 0
        for y in nums:
            tree.insert(y)
            while y > nums[i] * 2:
                tree.remove(nums[i])
                i += 1
            result = max(result, tree.find_max_xor(y))
        return result

# %% [markdown]
# ## 1003. Count Prefix and Suffix Pairs I
#
# You are given a 0-indexed string array words.
#
# Let's define a boolean function isPrefixAndSuffix that takes two strings, str1 and str2:
#
# isPrefixAndSuffix(str1, str2) returns true if str1 is both a prefix and a suffix of str2, and false otherwise.
# For example, isPrefixAndSuffix("aba", "ababa") is true because "aba" is a prefix of "ababa" and also a suffix, but isPrefixAndSuffix("abc", "abcd") is false.
#
# Return an integer denoting the number of index pairs (i, j) such that i < j, and isPrefixAndSuffix(words[i], words[j]) is true.
#
#
#
# Example 1:
#
# Input: words = ["a","aba","ababa","aa"]
# Output: 4
# Explanation: In this example, the counted index pairs are:
# i = 0 and j = 1 because isPrefixAndSuffix("a", "aba") is true.
# i = 0 and j = 2 because isPrefixAndSuffix("a", "ababa") is true.
# i = 0 and j = 3 because isPrefixAndSuffix("a", "aa") is true.
# i = 1 and j = 2 because isPrefixAndSuffix("aba", "ababa") is true.
# Therefore, the answer is 4.
# Example 2:
#
# Input: words = ["pa","papa","ma","mama"]
# Output: 2
# Explanation: In this example, the counted index pairs are:
# i = 0 and j = 1 because isPrefixAndSuffix("pa", "papa") is true.
# i = 2 and j = 3 because isPrefixAndSuffix("ma", "mama") is true.
# Therefore, the answer is 2.
# Example 3:
#
# Input: words = ["abab","ab"]
# Output: 0
# Explanation: In this example, the only valid index pair is i = 0 and j = 1, and isPrefixAndSuffix("abab", "ab") is false.
# Therefore, the answer is 0.
#
#
# Constraints:
# 1 <= words.length <= 50
# 1 <= words[i].length <= 10
# words[i] consists only of lowercase English letters.
#
# Hint 1
# Iterate through all index pairs (i, j), such that i < j, and check isPrefixAndSuffix(words[i], words[j]).
# Hint 2
# The answer is the total number of pairs where isPrefixAndSuffix(words[i], words[j]) == true.

# %%
# brute force approach
# time complexity: O(n^2 * m); n = len of words, and m = max length of longest word
# time complexity: O(1)
class Solution:
    def countPrefixSuffixPairs(self, words: List[str]) -> int:
        def isPrefixAndSuffix(str1, str2):
            if len(str1) > len(str2):
                return False
            return str2.startswith(str1) and str2.endswith(str1)
        n = len(words)
        result = 0
        for i in range(n):
            for j in range(i + 1, n):
                if isPrefixAndSuffix(words[i], words[j]):
                    result += 1
        return result
    
# Trie solution
# time complexity: O(m * n) n = len of words, m = len of max word
# space complexity: O(m * n)
class CountTrie:
    def __init__(self):
        self.root = {"count": 0}

    def insert(self, word):
        current = self.root
        current["count"] += 1
        for pair in zip(word, reversed(word)):
            if pair not in current:
                current[pair] = {"count": 0}
            current = current[pair]
        current["count"] += 1

    def countPrefAndSuf(self, word):
        current = self.root
        total_count = 0
        for pair in zip(word, reversed(word)):
            if pair not in current:
                break
            current = current[pair]
            total_count += current["count"]
        return total_count
    
class Solution:
    def countPrefixSuffixPairs(self, words: List[str]) -> int:
        trie = CountTrie()
        result = 0
        for word in words:
            result += trie.countPrefAndSuf(word)
            trie.insert(word)
        return result

# %% [markdown]
# ## 1004. Count Prefix and Suffix Pairs II
#
# - You are given a 0-indexed string array words.
#
# - Let's define a boolean function isPrefixAndSuffix that takes two strings, str1 and str2:
#
#     - isPrefixAndSuffix(str1, str2) returns true if str1 is both a prefix and a suffix of str2, and false otherwise.
#
# - For example, isPrefixAndSuffix("aba", "ababa") is true because "aba" is a prefix of "ababa" and also a suffix, but isPrefixAndSuffix("abc", "abcd") is false.
#
# - Return an integer denoting the number of index pairs (i, j) such that i < j, and isPrefixAndSuffix(words[i], words[j]) is true.
#
#
#
# - Example 1:
#     - Input: words = ["a","aba","ababa","aa"]
#     - Output: 4
#     - Explanation: In this example, the counted index pairs are:
# i = 0 and j = 1 because isPrefixAndSuffix("a", "aba") is true.
# i = 0 and j = 2 because isPrefixAndSuffix("a", "ababa") is true.
# i = 0 and j = 3 because isPrefixAndSuffix("a", "aa") is true.
# i = 1 and j = 2 because isPrefixAndSuffix("aba", "ababa") is true.
# Therefore, the answer is 4.
#
#
# - Example 2:
#     - Input: words = ["pa","papa","ma","mama"]
#     - Output: 2
#     - Explanation: In this example, the counted index pairs are:
# i = 0 and j = 1 because isPrefixAndSuffix("pa", "papa") is true.
# i = 2 and j = 3 because isPrefixAndSuffix("ma", "mama") is true.
# Therefore, the answer is 2.
#
# - Example 3:
#     - Input: words = ["abab","ab"]
#     - Output: 0
#     - Explanation: In this example, the only valid index pair is i = 0 and j = 1, and isPrefixAndSuffix("abab", "ab") is false.
# Therefore, the answer is 0.
#
#
# - Constraints:
#     - 1 <= words.length <= 10^5
#     - 1 <= words[i].length <= 10^5
#     - words[i] consists only of lowercase English letters.
#     - The sum of the lengths of all words[i] does not exceed 5 * 10^5.
#
#
# - Hint 1
#     - We can use a trie to solve it.
# - Hint 2
#     - Process all words[i] from left to right. The trie stores the pair (words[i][j], words[i][words[i].length - j - 1]) as a single character; we process all the words in this way.
# - Hint 3
#     - During insertion, keep a counter in each trie node, as in a normal trie. If the current node is the end of a word (namely, the pair on that node is (words[i][words[i].length - 1], words[i][0])), increase the node's counter by 1.
# - Hint 4
#     - From left to right, insert each word into the trie, and increase our final result by each node's counter when going down the trie during insertion. This means there was at least one word that is both a prefix and a suffix of the current word before.

# %%
# a trie will work for this problem I and II
class CountTrie:
    def __init__(self):
        self.root = {"count": 0}

    def insert(self, word):
        current = self.root
        current["count"] += 1
        for pair in zip(word, reversed(word)):
            if pair not in current:
                current[pair] = {"count": 0}
            current = current[pair]
        current["count"] += 1

    def countPrefAndSuf(self, word):
        current = self.root
        total_count = 0
        for pair in zip(word, reversed(word)):
            if pair not in current:
                break
            current = current[pair]
            total_count += current["count"]
        return total_count


class Solution:
    def countPrefixSuffixPairs(self, words: List[str]) -> int:
        trie = CountTrie()
        result = 0
        for word in words:
            result += trie.countPrefAndSuf(word)
            trie.insert(word)
        return result

# %% [markdown]
# ## 1005. Lexicographical Numbers
#
# - Given an integer n, return all the numbers in the range [1, n] sorted in lexicographical order.
#
# - You must write an algorithm that runs in O(n) time and uses O(1) extra space.
#
#
#
# - Example 1:
#     - Input: n = 13
#     - Output: [1,10,11,12,13,2,3,4,5,6,7,8,9]
#
# - Example 2:
#     - Input: n = 2
#     - Output: [1,2]
#
#
# - Constraints:
#     - 1 <= n <= 5 * 10^4

# %%
# iterative solution
# time complexity: O(n)
# space complexity: O(1)
class Solution:
    def lexicalOrder(self, n: int) -> List[int]:
        results = []
        val = 1
        for _ in range(n):
            results.append(val)
            if val * 10 <= n:
                val *= 10
            else:
                while val % 10 == 9 or val + 1 > n:
                    val //= 10
                val += 1

        return results
    
# virtual trie solution, using dfs on a virtual trie
class Solution:
    def lexicalOrder(self, n: int) -> List[int]:
        results = []

        def dfs_virtual_trie(current):
            if current > n:
                return

            results.append(current)

            for digit in range(10):
                next_num = current * 10 + digit
                if next_num > n:
                    break
                dfs_virtual_trie(next_num)

        for i in range(1, 10):
            dfs_virtual_trie(i)

        return results

# %% [markdown]
# ## 1006. Replace Words
#
# - In English, we have a concept called root, which can be followed by some other word to form another longer word - let's call this word derivative. For example, when the root "help" is followed by the word "ful", we can form a derivative "helpful".
#
# - Given a dictionary consisting of many roots and a sentence consisting of words separated by spaces, replace all the derivatives in the sentence with the root forming it. If a derivative can be replaced by more than one root, replace it with the root that has the shortest length.
#
# - Return the sentence after the replacement.
#
#
#
# - Example 1:
#     - Input: dictionary = ["cat","bat","rat"], sentence = "the cattle was rattled by the battery"
#     - Output: "the cat was rat by the bat"
#
# - Example 2:
#     - Input: dictionary = ["a","b","c"], sentence = "aadsfasf absbs bbab cadsfafs"
#     - Output: "a a b c"
#
#
# - Constraints:
#     - 1 <= dictionary.length <= 1000
#     - 1 <= dictionary[i].length <= 100
#     - dictionary[i] consists of only lower-case letters.
#     - 1 <= sentence.length <= 106
#     - sentence consists of only lower-case letters and spaces.
#     - The number of words in sentence is in the range [1, 1000]
#     - The length of each word in sentence is in the range [1, 1000]
#     - Every two consecutive words in sentence will be separated by exactly one space.
#     - sentence does not have leading or trailing spaces.

# %%
# Trie, the main method is to find the shortest prefix
# time complexity: O(n * r + l), n = len of words, r = num of roots, and l = longest word
class Trie:
    def __init__(self):
        self.tree = {}
        self.END = "."

    def add(self, word):
        current = self.tree
        for char in word:
            if char not in current:
                current.setdefault(char, {})
            current = current[char]
        current[self.END] = True

    def findRoot(self, word):
        current = self.tree
        prefix = []
        for char in word:
            if char not in current:
                break

            prefix.append(char)
            current = current[char]

            if self.END in current:
                return "".join(prefix)

        return word


class Solution:
    def replaceWords(self, dictionary: List[str], sentence: str) -> str:
        trie = Trie()
        for word in dictionary:
            trie.add(word)

        sents = sentence.split()
        results = []
        for word in sents:
            results.append(trie.findRoot(word))

        return " ".join(results)

# %% [markdown]
# ## 1007.  Implement Magic Dictionary
#
# - Design a data structure that is initialized with a list of different words. Provided a string, you should determine if you can change exactly one character in this string to match any word in the data structure.
#
# - Implement the MagicDictionary class:
#
#     - MagicDictionary() Initializes the object.
#     - void buildDict(String[] dictionary) Sets the data structure with an array of distinct strings dictionary.
#     - bool search(String searchWord) Returns true if you can change exactly one character in searchWord to match any string in the data structure, otherwise returns false.
#
#
# - Example 1:
#     - Input
# ["MagicDictionary", "buildDict", "search", "search", "search", "search"]
# [[], [["hello", "leetcode"]], ["hello"], ["hhllo"], ["hell"], ["leetcoded"]]
#     - Output
# [null, null, false, true, false, false]
#     - Explanation
# MagicDictionary magicDictionary = new MagicDictionary();
# magicDictionary.buildDict(["hello", "leetcode"]);
# magicDictionary.search("hello"); // return False
# magicDictionary.search("hhllo"); // We can change the second 'h' to 'e' to match "hello" so we return True
# magicDictionary.search("hell"); // return False
# magicDictionary.search("leetcoded"); // return False
#
#
# - Constraints:
#     - 1 <= dictionary.length <= 100
#     - 1 <= dictionary[i].length <= 100
#     - dictionary[i] consists of only lower-case English letters.
#     - All the strings in dictionary are distinct.
#     - 1 <= searchWord.length <= 100
#     - searchWord consists of only lower-case English letters.
#     - buildDict will be called only once before search.
#     - At most 100 calls will be made to search.

# %%
# Fixed-length bucket matching 
# time complexity: O(s) -> build, s = total num of letters 
# O(n * k) -> search, n = len of words, k = length of searchWord 
# space complexity: O(s)
from collections import defaultdict
class MagicDictionary:

    def __init__(self):
        self.buckets = defaultdict(list)

    def buildDict(self, dictionary) -> None:
        for word in dictionary:
            self.buckets[len(word)].append(word)

    def search(self, searchWord: str) -> bool:

        return any(sum(char1 != char2 for char1, char2 in zip(searchWord, candidates)) == 1
                   for candidates in self.buckets[len(searchWord)])


# Your MagicDictionary object will be instantiated and called as such:
# obj = MagicDictionary()
# obj.buildDict(dictionary)
# param_2 = obj.search(searchWord)

# Trie solution
# slower than the fixed length bucket solution
# time complexity: 
# build: O(n * l) n = len of dictionary, and l is max len of word
# search: O(w * 26^l) w = len of word, 
# space complexity: O(n * l)
class MagicDictionary:

    def __init__(self):
        self.tree = {}
        self.END = "."

    def buildDict(self, dictionary) -> None:
        for word in dictionary:
            current = self.tree
            for char in word:
                if char not in current:
                    current[char] = {}
                current = current[char]
            current[self.END] = True

    def search(self, searchWord: str) -> bool:
        current = self.tree
        def dfs(node, index, is_modified):
            if index == len(searchWord):
                return is_modified and self.END in node

            target = searchWord[index]
            
            for next_char in node:
                if next_char == self.END:
                    continue
                
                if next_char != target:
                    if not is_modified:
                        if dfs(node[next_char], index + 1, True):
                            return True
                else:
                    if dfs(node[next_char], index + 1, is_modified):
                        return True
                        
            return False

        return dfs(current, 0, False)
        


# Your MagicDictionary object will be instantiated and called as such:
# obj = MagicDictionary()
# obj.buildDict(dictionary)
# param_2 = obj.search(searchWord)

# %% [markdown]
# ## 1008. Map Sum Pairs
#
# - Design a map that allows you to do the following:
#
#     - Maps a string key to a given value.
#     - Returns the sum of the values that have a key with a prefix equal to a given string.
#
# - Implement the MapSum class:
#
#     - MapSum() Initializes the MapSum object.
#     - void insert(String key, int val) Inserts the key-val pair into the map. If the key already existed, the original key-value pair will be overridden to the new one.
#     - int sum(string prefix) Returns the sum of all the pairs' value whose key starts with the prefix.
#
#
# - Example 1:
#     - Input: ["MapSum", "insert", "sum", "insert", "sum"]
# [[], ["apple", 3], ["ap"], ["app", 2], ["ap"]]
#     - Output: [null, null, 3, null, 5]
#     - Explanation
# MapSum mapSum = new MapSum();
# mapSum.insert("apple", 3);
# mapSum.sum("ap");           // return 3 (apple = 3)
# mapSum.insert("app", 2);
# mapSum.sum("ap");           // return 5 (apple + app = 3 + 2 = 5)
#
#
# - Constraints:
#     - 1 <= key.length, prefix.length <= 50
#     - key and prefix consist of only lowercase English letters.
#     - 1 <= val <= 1000
#     - At most 50 calls will be made to insert and sum.

# %%
# Trie with a running sum and replace the new val when inserted
# time complexity: O(n) n = len of keys
# space complexity: O(n * m * C) m = max len of key, c = size of character set
from collections import defaultdict
class MapSum:

    def __init__(self):
        self.tree = {"total": 0}
        self.hash = defaultdict(int)

    def insert(self, key: str, val: int) -> None:
        current = self.tree
        x = val - self.hash[key]
        self.hash[key] = val
        for char in key:
            if char not in current:
                current.setdefault(char, {"total": 0})
            current = current[char]
            current["total"] += x

    def sum(self, prefix: str) -> int:
        current = self.tree
        for char in prefix:
            if char not in current:
                return 0
            current = current[char]
        return current["total"]


# Your MapSum object will be instantiated and called as such:
# obj = MapSum()
# obj.insert(key,val)
# param_2 = obj.sum(prefix)

# %% [markdown]
# ## 1009. Longest Word in Dictionary
#
# - Given an array of strings words representing an English Dictionary, return the longest word in words that can be built one character at a time by other words in words.
#
# - If there is more than one possible answer, return the longest word with the smallest lexicographical order. If there is no answer, return the empty string.
#
# - Note that the word should be built from left to right with each additional character being added to the end of a previous word.
#
#
#
# - Example 1:
#     - Input: words = ["w","wo","wor","worl","world"]
#     - Output: "world"
#     - Explanation: The word "world" can be built one character at a time by "w", "wo", "wor", and "worl".
#
# - Example 2:
#     - Input: words = ["a","banana","app","appl","ap","apply","apple"]
#     - Output: "apple"
#     - Explanation: Both "apply" and "apple" can be built from other words in the dictionary. However, "apple" is lexicographically smaller than "apply".
#
#
# - Constraints:
#     - 1 <= words.length <= 1000
#     - 1 <= words[i].length <= 30
#     - words[i] consists of lowercase English letters.
#
# - Hint 1
#     - For every word in the input list, we can check whether all prefixes of that word are in the input list by using a Set.

# %%
# Trie solution. a little different for the search also
# time complexity: O(n), n = len of all words
# space complexity: O(n)
class Trie:
    def __init__(self):
        self.tree = {}
        self.END = "."

    def insert(self, word):
        current = self.tree
        for char in word:
            if char not in current:
                current.setdefault(char, {})
            current = current[char]
        current[self.END] = True

    def search(self, word):
        current = self.tree
        for char in word:
            if char not in word:
                return False
            current = current[char]
            if self.END not in current:
                return False
        return True


class Solution:
    def longestWord(self, words: List[str]) -> str:
        trie = Trie()
        for word in words:
            trie.insert(word)

        result = ""
        for word in words:
            if trie.search(word) and (
                len(result) < len(word) or (
                    len(result) == len(word) and result > word)
            ):
                result = word
        return result

# %% [markdown]
# ## 1010. Number of Matching Subsequences
#
# - Given a string s and an array of strings words, return the number of words[i] that is a subsequence of s.
#
# - A subsequence of a string is a new string generated from the original string with some characters (can be none) deleted without changing the relative order of the remaining characters.
#
# - For example, "ace" is a subsequence of "abcde".
#
#
# - Example 1:
#     - Input: s = "abcde", words = ["a","bb","acd","ace"]
#     - Output: 3
#     - Explanation: There are three strings in words that are a subsequence of s: "a", "acd", "ace".
#
# - Example 2:
#     - Input: s = "dsahjpjauf", words = ["ahjpjau","ja","ahbwzgqnuk","tnmlanowax"]
#     - Output: 2
#
#
# - Constraints:
#     - 1 <= s.length <= 5 * 10^4
#     - 1 <= words.length <= 5000
#     - 1 <= words[i].length <= 50
#     - s and words[i] consist of only lowercase English letters.

# %%
# using a queue
# time complexity: O(n * m), n = len  of words, and m = character of s
# space complexity: O(n * m)
from collections import deque
class Solution:
    def numMatchingSubseq(self, s: str, words: List[str]) -> int:
        deck = defaultdict(deque)
        for word in words:
            deck[word[0]].append(word)
        result = 0
        for char in s:
            for _ in range(len(deck[char])):
                temp = deck[char].popleft()
                if len(temp) == 1:
                    result += 1
                else:
                    deck[temp[1]].append(temp[1:])
        return result

# trie solution, so slow, but it works the bucket is a lot quicker
# time complexity: add: O(W * L), W = number of words, L = Maximum len of any word, 
# match_str: O(V * N) V = all vertex in Trie, s.find takes N time; length of string
# total: O(W * L + V * N)
# space complexity: O(W * L)
# could speed up with s.find with using a list and bisect, but still a lot slower than the bucket version.
# good to know.
class Trie:
    def __init__(self):
        self.tree = {"count": 0}

    def add(self, word):
        current = self.tree
        for char in word:
            if char not in current:
                current[char] = {"count": 0}
            current = current[char]
        current["count"] += 1

    def match_str(self, word):
        queue = [(self.tree, 0)]
        result = 0
        while queue:
            node, index = queue.pop()

            result += node["count"]

            for char, child_node in node.items():
                next_index =  word.find(char, index)
                if next_index != -1:
                    queue.append((child_node, next_index + 1))
        return result

class Solution:
    def numMatchingSubseq(self, s: str, words: List[str]) -> int:
        trie = Trie()
        for word in words:
            trie.add(word)
        return trie.match_str(s)

# %% [markdown]
# ## 1011.  Count Numbers with Unique Digits
#
# - Given an integer n, return the count of all numbers with unique digits, x, where 0 <= x < 10n.
#
#
#
# - Example 1:
#     - Input: n = 2
#     - Output: 91
#     - Explanation: The answer should be the total numbers in the range of 0 ≤ x < 100, excluding 11,22,33,44,55,66,77,88,99
#
# - Example 2:
#     - Input: n = 0
#     - Output: 1
#
#
# - Constraints:
#     - 0 <= n <= 8
#
# - Hint 1
#     - A direct way is to use the backtracking approach.
# - Hint 2
#     - Backtracking should contains three states which are (the current number, number of steps to get that number and a bitmask which represent which number is marked as visited so far in the current number). Start with state (0,0,0) and count all valid number till we reach number of steps equals to 10n.
# - Hint 3
#     - This problem can also be solved using a dynamic programming approach and some knowledge of combinatorics.
# - Hint 4
#     - Let f(k) = count of numbers with unique digits with length equals k.
# - Hint 5
#     - f(1) = 10, ..., f(k) = 9 * 9 * 8 * ... (9 - k + 2) [The first factor is 9 because a number cannot start with 0].

# %%
# digit dynamic programming
# time complexity: O(n * 2^10 * 10) n = length of number
# space complexity: O(n * 2^10 )
class Solution:
    def countNumbersWithUniqueDigits(self, n: int) -> int:
        memo = {}

        def dfs(index, is_leading, visited_masked):
            if index == n:
                return 1

            if (index, is_leading, visited_masked) in memo:
                return memo[(index, is_leading, visited_masked)]

            count = 0
            for digit in range(10):
                if not is_leading and (visited_masked >> digit) & 1:
                    continue

                if digit == 0 and is_leading:
                    count += dfs(index + 1, True, visited_masked)
                else:
                    new_masked = visited_masked | (1 << digit)
                    count += dfs(index + 1, False, new_masked)

            memo[(index, is_leading, visited_masked)] = count
            return count

        return dfs(0, True, 0)

# %% [markdown]
# ## 1012. Short Encoding of Words
#
# - A valid encoding of an array of words is any reference string s and array of indices indices such that:
#
#     - words.length == indices.length
#     - The reference string s ends with the '#' character.
#     - For each index indices[i], the substring of s starting from indices[i] and up to (but not including) the next '#' character is equal to words[i].
#
# - Given an array of words, return the length of the shortest reference string s possible of any valid encoding of words.
#
#
#
# - Example 1:
#     - Input: words = ["time", "me", "bell"]
#     - Output: 10
#     - Explanation: A valid encoding would be s = "time#bell#" and indices = [0, 2, 5].
# words[0] = "time", the substring of s starting from indices[0] = 0 to the next '#' is underlined in "time#bell#"
# words[1] = "me", the substring of s starting from indices[1] = 2 to the next '#' is underlined in "time#bell#"
# words[2] = "bell", the substring of s starting from indices[2] = 5 to the next '#' is underlined in "time#bell#"
#
# - Example 2:
#     - Input: words = ["t"]
#     - Output: 2
#     - Explanation: A valid encoding would be s = "t#" and indices = [0].
#
#
# - Constraints:
#     - 1 <= words.length <= 2000
#     - 1 <= words[i].length <= 7
#     - words[i] consists of only lowercase letters.

# %%
# Trie, need to know how to count char up to the leaf, then count 1 more for leaf
# time complexity: add: O(W * L), W = number of words, L = Maximum len of any word,
# time complexity: get_encoding: O(V * N), V = all vertext (leaf), N = len of all words minus duplicates
# space complexity: O(W * L)
# the dfs vs queue version: dfs will take up as much memory as the length of the word, 
# the queue version will scale the widest layer of the Trie (how many words branch out from a single word)
class Trie:
    def __init__(self):
        self.tree = {}
        self.END = "."

    def add(self, word):
        current = self.tree
        for char in reversed(word):
            if char not in current:
                current[char] = {}
            current = current[char]
        current[self.END] = True

    def get_encoding(self):

        def dfs(node, cur_result):
            is_leaf, result = True, 0
            for char in node.keys():
                if node[char] != True:
                    is_leaf = False
                    result += dfs(node[char], cur_result + 1)
            if is_leaf:
                result += cur_result
            return result

        return dfs(self.tree, 1)
    
    # another method to do dfs with only the node
    def get_encoding2(self):

        def dfs(node):
            is_leaf = len(node) == 1 and self.END in node
            result = 1 if is_leaf else 0

            for char in node:
                if char != self.END:
                    is_leaf = False
                    result += 1 + dfs(node[char])

            return result

        return dfs(self.tree)



class Solution:
    def minimumLengthEncoding(self, words: List[str]) -> int:
        trie = Trie()
        for word in words:
            trie.add(word)

        return trie.get_encoding()

# %% [markdown]
# ## 1013. Camelcase Matching
#
# - Given an array of strings queries and a string pattern, return a boolean array answer where answer[i] is true if queries[i] matches pattern, and false otherwise.
#
# - A query word queries[i] matches pattern if you can insert lowercase English letters into the pattern so that it equals the query. You may insert a character at any position in pattern or you may choose not to insert any characters at all.
#
#
#
# - Example 1:
#     - Input: queries = ["FooBar","FooBarTest","FootBall","FrameBuffer","ForceFeedBack"], pattern = "FB"
#     - Output: [true,false,true,true,false]
#     - Explanation: "FooBar" can be generated like this "F" + "oo" + "B" + "ar".
# "FootBall" can be generated like this "F" + "oot" + "B" + "all".
# "FrameBuffer" can be generated like this "F" + "rame" + "B" + "uffer".
#
# - Example 2:
#     - Input: queries = ["FooBar","FooBarTest","FootBall","FrameBuffer","ForceFeedBack"], pattern = "FoBa"
#     - Output: [true,false,true,false,false]
#     - Explanation: "FooBar" can be generated like this "Fo" + "o" + "Ba" + "r".
# "FootBall" can be generated like this "Fo" + "ot" + "Ba" + "ll".
#
# - Example 3:
#     - Input: queries = ["FooBar","FooBarTest","FootBall","FrameBuffer","ForceFeedBack"], pattern = "FoBaT"
#     - Output: [false,true,false,false,false]
#     - Explanation: "FooBarTest" can be generated like this "Fo" + "o" + "Ba" + "r" + "T" + "est".
#
#
# - Constraints:
#     - 1 <= pattern.length, queries.length <= 100
#     - 1 <= queries[i].length <= 100
#     - queries[i] and pattern consist of English letters.
#
# - Hint 1
#     - Given a single pattern and word, how can we solve it?
# - Hint 2
#     - One way to do it is using a DP (pos1, pos2) where pos1 is a pointer to the word and pos2 to the pattern and returns true if we can match the pattern with the given word.
# - Hint 3
#     - We have two scenarios: The first one is when `word[pos1] == pattern[pos2]`, then the transition will be just DP(pos1 + 1, pos2 + 1). The second scenario is when `word[pos1]` is lowercase then we can add this character to the pattern so that the transition is just DP(pos1 + 1, pos2) The case base is `if (pos1 == n && pos2 == m) return true;` Where n and m are the sizes of the strings word and pattern respectively.

# %%
# two pointers solution
# time complexity: O(n * m) n = len of queries and m = len of pattern
# space complexity: O(1)
class Solution:
    def camelMatch(self, queries: List[str], pattern: str) -> List[bool]:
        def check(query, pattern):
            m = len(query)
            n = len(pattern)
            i = j = 0
            while j < n:
                while i < m and query[i] != pattern[j] and query[i].islower():
                    i += 1
                if i == m or query[i] != pattern[j]:
                    return False
                i += 1
                j += 1
            while i < m and query[i].islower():
                i += 1
            return i == m

        return [check(query, pattern) for query in queries]
    
# Trie solution, a little slower than the two pointers version, but it seems easier to reason and code
# the key insight is to add the pattern and check the query against the pattern.
# time complexity: add: O(W * L), W = number of words, L = Maximum len of any word,
# time complexity: check: O(W * L)
# space complexity: O(W * L)
class Trie:
    def __init__(self):
        self.tree = {}
        self.END = "."

    def add(self, word):
        current = self.tree
        for char in word:
            if char not in current:
                current[char] = {}
            current = current[char]
        current[self.END] = True

    def check(self, query):
        current = self.tree
        for char in query:
            if char in current:
                current = current[char]
            elif char.isupper():
                return False
            else:
                continue
        return self.END in current


class Solution:
    def camelMatch(self, queries: List[str], pattern: str) -> List[bool]:
        trie = Trie()
        trie.add(pattern)
        
        return [trie.check(query) for query in queries]

# %% [markdown]
# ## 1014. Remove Sub-Folders from the Filesystem
#
# - Given a list of folders folder, return the folders after removing all sub-folders in those folders. You may return the answer in any order.
#
# - If a folder[i] is located within another folder[j], it is called a sub-folder of it. A sub-folder of folder[j] must start with folder[j], followed by a "/". For example, "/a/b" is a sub-folder of "/a", but "/b" is not a sub-folder of "/a/b/c".
#
# - The format of a path is one or more concatenated strings of the form: '/' followed by one or more lowercase English letters.
#
#     - For example, "/leetcode" and "/leetcode/problems" are valid paths while an empty string and "/" are not.
#
#
# - Example 1:
#     - Input: folder = ["/a","/a/b","/c/d","/c/d/e","/c/f"]
#     - Output: ["/a","/c/d","/c/f"]
#     - Explanation: Folders "/a/b" is a subfolder of "/a" and "/c/d/e" is inside of folder "/c/d" in our filesystem.
#
# - Example 2:
#     - Input: folder = ["/a","/a/b/c","/a/b/d"]
#     - Output: ["/a"]
#     - Explanation: Folders "/a/b/c" and "/a/b/d" will be removed because they are subfolders of "/a".
#
# - Example 3:
#     - Input: folder = ["/a/b/c","/a/b/ca","/a/b/d"]
#     - Output: ["/a/b/c","/a/b/ca","/a/b/d"]
#
#
# - Constraints:
#     - 1 <= folder.length <= 4 * 10^4
#     - 2 <= folder[i].length <= 100
#     - folder[i] contains only lowercase letters and '/'.
#     - folder[i] always starts with the character '/'.
#     - Each folder name is unique.
#
# - Hint 1
#     - Sort the folders lexicographically.
# - Hint 2
#     - Insert the current element in an array and then loop until we get rid of all of their subfolders, repeat this until no element is left.

# %%
# trie solution, with backtrack 
# time complexity:
class Trie:
    def __init__(self):
        self.tree = {}
        self.END = "."

    def add(self, path):
        current = self.tree
        word = path.split("/")
        for char in word:
            if char not in current:
                current[char] = {}
            current = current[char]
        current[self.END] = True

    def get_path(self):
        results = []

        def backtrack(node, path):
            if self.END in node:
                results.append("/".join(path))

            for char in node:
                path.append(char)
                if self.END not in node:
                    backtrack(node[char], path)
                path.pop()
        backtrack(self.tree, [])

        return results


class Solution:
    def removeSubfolders(self, folder: List[str]) -> List[str]:
        trie = Trie()
        for path in folder:
            trie.add(path)

        return trie.get_path()
    
# simulation based on hints, a lot faster
# time complexity: O(n logn) for the sorting
# space complexity: O(1)

class Solution:
    def removeSubfolders(self, folder: List[str]) -> List[str]:
        folder.sort()
        results = [folder[0]]
        n = len(folder)

        for i in range(1, n):
            last_folder = results[-1] + "/"

            if folder[i].startswith(last_folder):
                continue
            results.append(folder[i])

        return results

# %% [markdown]
# ## 1015. Extra Characters in a String
#
# - You are given a 0-indexed string s and a dictionary of words dictionary. You have to break s into one or more non-overlapping substrings such that each substring is present in dictionary. There may be some extra characters in s which are not present in any of the substrings.
#
# - Return the minimum number of extra characters left over if you break up s optimally.
#
#
#
# - Example 1:
#     - Input: s = "leetscode", dictionary = ["leet","code","leetcode"]
#     - Output: 1
#     - Explanation: We can break s in two substrings: "leet" from index 0 to 3 and "code" from index 5 to 8. There is only 1 unused character (at index 4), so we return 1.
#
# - Example 2:
#     - Input: s = "sayhelloworld", dictionary = ["hello","world"]
#     - Output: 3
#     - Explanation: We can break s in two substrings: "hello" from index 3 to 7 and "world" from index 8 to 12. The characters at indices 0, 1, 2 are not used in any substring and thus are considered as extra characters. Hence, we return 3.
#
#
# - Constraints:
#     - 1 <= s.length <= 50
#     - 1 <= dictionary.length <= 50
#     - 1 <= dictionary[i].length <= 50
#     - dictionary[i] and s consists of only lowercase English letters
#     - dictionary contains distinct words
#
# - Hint 1
#     - Can we use Dynamic Programming here?
# - Hint 2
#     - Define DP[i] as the min extra character if breaking up s[0:i] optimally.

# %%
# Trie + dynamic programming
# time complexity: O(N^2 + M * K); N total char in strings, M = average len of dictionary, K len of dictionary
# space complexity: O(N + M * K)
class Trie:
    def __init__(self):
        self.tree = {}
        self.END = "."

    def add(self, word):
        current = self.tree
        for char in word:
            if char not in current:
                current[char] = {}
            current = current[char]
        current[self.END] = True

    def count_extra_char(self, pattern):
        n = len(pattern)
        # the base case is at the end
        memo = {n: 0} 

        def dfs(start):
            if start in memo:
                return memo[start]

            # option 1, we skip
            result = dfs(start + 1) + 1
            node = self.tree

            # option 2, the word is accounted for
            for end in range(start, n):
                if pattern[end] not in node:
                    break
                node = node[pattern[end]]
                if self.END in node:
                    result = min(result, dfs(end + 1))

            memo[start] = result
            return result

        return dfs(0)


class Solution:
    def minExtraChar(self, s: str, dictionary: List[str]) -> int:
        trie = Trie()
        for word in dictionary:
            trie.add(word)

        return trie.count_extra_char(s)

# Trie with iterative dp solution
# time complexity: O(N^2 + M * L), N = len of s, M = len of words, L = max len of any word
# space complexity: O(M * L + N), the Tries and dp array
class Trie:
    def __init__(self):
        self.tree = {}
        self.END = "."

    def add(self, word):
        current = self.tree
        for char in word:
            if char not in current:
                current[char] = {}
            current = current[char]
        current[self.END] = True


class Solution:
    def minExtraChar(self, s: str, dictionary: List[str]) -> int:
        trie = Trie()
        for word in dictionary:
            trie.add(word)

        n = len(s)
        dp = [0] * (n + 1)

        for start in range(n - 1, -1, -1):
            dp[start] = 1 + dp[start + 1]

            node = trie.tree
            for end in range(start, n):
                if s[end] not in node:
                    break

                node = node[s[end]]
                if trie.END in node:
                    dp[start] = min(dp[start], dp[end + 1])

        return dp[0]

# %% [markdown]
# ## 1016. K Divisible Elements Subarrays
#
# - Given an integer array nums and two integers k and p, return the number of distinct subarrays, which have at most k elements that are divisible by p.
#
# - Two arrays nums1 and nums2 are said to be distinct if:
#
#     - They are of different lengths, or
#     - There exists at least one index i where nums1[i] != nums2[i].
#
# - A subarray is defined as a non-empty contiguous sequence of elements in an array.
#
#
#
# - Example 1:
#     - Input: nums = [2,3,3,2,2], k = 2, p = 2
#     - Output: 11
#     - Explanation:
# The elements at indices 0, 3, and 4 are divisible by p = 2.
# The 11 distinct subarrays which have at most k = 2 elements divisible by 2 are:
# [2], [2,3], [2,3,3], [2,3,3,2], [3], [3,3], [3,3,2], [3,3,2,2], [3,2], [3,2,2], and [2,2].
# Note that the subarrays [2] and [3] occur more than once in nums, but they should each be counted only once.
# The subarray [2,3,3,2,2] should not be counted because it has 3 elements that are divisible by 2.
#
# - Example 2:
#     - Input: nums = [1,2,3,4], k = 4, p = 1
#     - Output: 10
#     - Explanation:
# All element of nums are divisible by p = 1.
# Also, every subarray of nums will have at most 4 elements that are divisible by 1.
# Since all subarrays are distinct, the total number of subarrays satisfying all the constraints is 10.
#
#
# - Constraints:
#     - 1 <= nums.length <= 200
#     - 1 <= nums[i], p <= 200
#     - 1 <= k <= nums.length
#
#
# - Hint 1
#     - Enumerate all subarrays and find the ones that satisfy all the conditions.
# - Hint 2
#     - Use any suitable method to hash the subarrays to avoid duplicates.

# %%
# enumeration for subarray generation, add contraints for problem, then use Trie for deduplication
# could also use rolling hash
# time complexity: O(n^2) 
# space complexity: O(n^2)
class TrieNode:
    def __init__(self):
        self.tree = {}


class Solution:
    def countDistinct(self, nums: List[int], k: int, p: int) -> int:
        n = len(nums)
        result = 0
        root = TrieNode()

        for i in range(n):
            divisible_count = 0
            current = root

            for j in range(i, n):
                if nums[j] % p == 0:
                    divisible_count += 1

                if divisible_count > k:
                    break

                if nums[j] not in current.tree:
                    current.tree[nums[j]] = TrieNode()
                    result += 1

                current = current.tree[nums[j]]

        return result

# %% [markdown]
# ## 1017.

# %% [markdown]
# ## 1018.

# %% [markdown]
# ## 1019.

# %% [markdown]
# ## 1020.

# %% [markdown]
# ## 1021.

# %% [markdown]
# ## 1022.

# %% [markdown]
# ## 1023.

# %% [markdown]
# ## 1024.

# %% [markdown]
# ## 1025.

# %% [markdown]
# ## 1026.

# %% [markdown]
# ## 1027.

# %% [markdown]
# ## 1028.

# %% [markdown]
# ## 1029.

# %% [markdown]
# ## 1030.

# %% [markdown]
# ## 1031.

# %% [markdown]
# ## 1032.

# %% [markdown]
# ## 1033.

# %% [markdown]
# ## 1034.

# %% [markdown]
# ## 1035.

# %% [markdown]
# ## 1036.

# %% [markdown]
# ## 1037.

# %% [markdown]
# ## 1038.

# %% [markdown]
# ## 1039.

# %% [markdown]
# ## 1040.

# %% [markdown]
# ## 1041.

# %% [markdown]
# ## 1042.

# %% [markdown]
# ## 1043.

# %% [markdown]
# ## 1044.

# %% [markdown]
# ## 1045.

# %% [markdown]
# ## 1046.

# %% [markdown]
# ## 1047.

# %% [markdown]
# ## 1048.

# %% [markdown]
# ## 1049.

# %% [markdown]
# ## 1050.

# %% [markdown]
# # Questions 1051-1100

# %% [markdown]
# ## 1051.

# %% [markdown]
# ## 1052.

# %% [markdown]
# ## 1053.

# %% [markdown]
# ## 1054.

# %% [markdown]
# ## 1055.

# %% [markdown]
# ## 1056.

# %% [markdown]
# ## 1057.

# %% [markdown]
# ## 1058.

# %% [markdown]
# ## 1059.

# %% [markdown]
# ## 1060.

# %% [markdown]
# ## 1061.

# %% [markdown]
# ## 1062.

# %% [markdown]
# ## 1063.

# %% [markdown]
# ## 1064.

# %% [markdown]
# ## 1065.

# %% [markdown]
# ## 1066.

# %% [markdown]
# ## 1067.

# %% [markdown]
# ## 1068.

# %% [markdown]
# ## 1069.

# %% [markdown]
# ## 1070.

# %% [markdown]
# ## 1071.

# %% [markdown]
# ## 1072.

# %% [markdown]
# ## 1073.

# %% [markdown]
# ## 1074.

# %% [markdown]
# ## 1075.

# %% [markdown]
# ## 1076.

# %% [markdown]
# ## 1077.

# %% [markdown]
# ## 1078.

# %% [markdown]
# ## 1079.

# %% [markdown]
# ## 1080.

# %% [markdown]
# ## 1081.

# %% [markdown]
# ## 1082.

# %% [markdown]
# ## 1083.

# %% [markdown]
# ## 1084.

# %% [markdown]
# ## 1085.

# %% [markdown]
# ## 1086.

# %% [markdown]
# ## 1087.

# %% [markdown]
# ## 1088.

# %% [markdown]
# ## 1089.

# %% [markdown]
# ## 1090.

# %% [markdown]
# ## 1091.

# %% [markdown]
# ## 1092.

# %% [markdown]
# ## 1093.

# %% [markdown]
# ## 1094.

# %% [markdown]
# ## 1095.

# %% [markdown]
# ## 1096.

# %% [markdown]
# ## 1097.

# %% [markdown]
# ## 1098.

# %% [markdown]
# ## 1099.

# %% [markdown]
# ## 1100.

# %% [markdown]
# # Questions 1101-1150

# %% [markdown]
# ## 1101.

# %% [markdown]
# ## 1102.

# %% [markdown]
# ## 1103.

# %% [markdown]
# ## 1104.

# %% [markdown]
# ## 1105.

# %% [markdown]
# ## 1106.

# %% [markdown]
# ## 1107.

# %% [markdown]
# ## 1108.

# %% [markdown]
# ## 1109.

# %% [markdown]
# ## 1110.

# %% [markdown]
# ## 1111.

# %% [markdown]
# ## 1112.

# %% [markdown]
# ## 1113.

# %% [markdown]
# ## 1114.

# %% [markdown]
# ## 1115.

# %% [markdown]
# ## 1116.

# %% [markdown]
# ## 1117.

# %% [markdown]
# ## 1118.

# %% [markdown]
# ## 1119.

# %% [markdown]
# ## 1120.

# %% [markdown]
# ## 1121.

# %% [markdown]
# ## 1122.

# %% [markdown]
# ## 1123.

# %% [markdown]
# ## 1124.

# %% [markdown]
# ## 1125.

# %% [markdown]
# ## 1126.

# %% [markdown]
# ## 1127.

# %% [markdown]
# ## 1128.

# %% [markdown]
# ## 1129.

# %% [markdown]
# ## 1130.

# %% [markdown]
# ## 1131.

# %% [markdown]
# ## 1132.

# %% [markdown]
# ## 1133.

# %% [markdown]
# ## 1134.

# %% [markdown]
# ## 1135.

# %% [markdown]
# ## 1136.

# %% [markdown]
# ## 1137.

# %% [markdown]
# ## 1138.

# %% [markdown]
# ## 1139.

# %% [markdown]
# ## 1140.

# %% [markdown]
# ## 1141.

# %% [markdown]
# ## 1142.

# %% [markdown]
# ## 1143.

# %% [markdown]
# ## 1144.

# %% [markdown]
# ## 1145.

# %% [markdown]
# ## 1146.

# %% [markdown]
# ## 1147.

# %% [markdown]
# ## 1148.

# %% [markdown]
# ## 1149.

# %% [markdown]
# ## 1150.

# %% [markdown]
# # Questions 1150-1200

# %% [markdown]
# ## 1151.

# %% [markdown]
# ## 1152.

# %% [markdown]
# ## 1153.

# %% [markdown]
# ## 1154.

# %% [markdown]
# ## 1155.

# %% [markdown]
# ## 1156.

# %% [markdown]
# ## 1157.

# %% [markdown]
# ## 1158.

# %% [markdown]
# ## 1159.

# %% [markdown]
# ## 1160.

# %% [markdown]
# ## 1161.

# %% [markdown]
# ## 1162.

# %% [markdown]
# ## 1163.

# %% [markdown]
# ## 1164.

# %% [markdown]
# ## 1165.

# %% [markdown]
# ## 1166.

# %% [markdown]
# ## 1167.

# %% [markdown]
# ## 1168.

# %% [markdown]
# ## 1169.

# %% [markdown]
# ## 1170.

# %% [markdown]
# ## 1171.

# %% [markdown]
# ## 1172.

# %% [markdown]
# ## 1173.

# %% [markdown]
# ## 1174.

# %% [markdown]
# ## 1175.

# %% [markdown]
# ## 1176.

# %% [markdown]
# ## 1177.

# %% [markdown]
# ## 1178.

# %% [markdown]
# ## 1179.

# %% [markdown]
# ## 1180.

# %% [markdown]
# ## 1181.

# %% [markdown]
# ## 1182.

# %% [markdown]
# ## 1183.

# %% [markdown]
# ## 1184.

# %% [markdown]
# ## 1185.

# %% [markdown]
# ## 1186.

# %% [markdown]
# ## 1187.

# %% [markdown]
# ## 1188.

# %% [markdown]
# ## 1189.

# %% [markdown]
# ## 1190.

# %% [markdown]
# ## 1191.

# %% [markdown]
# ## 1192.

# %% [markdown]
# ## 1193.

# %% [markdown]
# ## 1194.

# %% [markdown]
# ## 1195.

# %% [markdown]
# ## 1196.

# %% [markdown]
# ## 1197.

# %% [markdown]
# ## 1198.

# %% [markdown]
# ## 1199.

# %% [markdown]
# ## 1200.
