# %% [markdown]
# # Practice 6
# - More LeetCode Questions

# %% [markdown]
# ## 1001.

# %% [markdown]
# ## 1002.

# %% [markdown]
# ## 1003.

# %% [markdown]
# ## 1004.

# %% [markdown]
# ## 1005.

# %% [markdown]
# ## 1006.

# %% [markdown]
# ## 1007.

# %% [markdown]
# ## 1008.

# %% [markdown]
# ## 1009.

# %% [markdown]
# ## 1010.

# %% [markdown]
# ## 1011.

# %% [markdown]
# ## 1012.

# %% [markdown]
# ## 1013.

# %% [markdown]
# ## 1014.

# %% [markdown]
# ## 1015.

# %% [markdown]
# ## 1016.

# %% [markdown]
# ## 1017.

# %% [markdown]
# ## 1018.

# %% [markdown]
# ## 1019.

# %% [markdown]
# ## 1020.

# %% [markdown]
# ## 1021.

# %% [markdown]
# ## 1022.

# %% [markdown]
# ## 1023.

# %% [markdown]
# ## 1024.

# %% [markdown]
# ## 1025.

# %% [markdown]
# ## 1026.

# %% [markdown]
# ## 1027.

# %% [markdown]
# ## 1028.

# %% [markdown]
# ## 1029.

# %% [markdown]
# ## 1030.

# %% [markdown]
# ## 1031.

# %% [markdown]
# ## 1032.

# %% [markdown]
# ## 1033.

# %% [markdown]
# ## 1034.

# %% [markdown]
# ## 1035.

# %% [markdown]
# ## 1036.

# %% [markdown]
# ## 1037.

# %% [markdown]
# ## 1038.

# %% [markdown]
# ## 1039.

# %% [markdown]
# ## 1040.

# %% [markdown]
# ## 1041.

# %% [markdown]
# ## 1042.

# %% [markdown]
# ## 1043.

# %% [markdown]
# ## 1044.

# %% [markdown]
# ## 1045.

# %% [markdown]
# ## 1046.

# %% [markdown]
# ## 1047.

# %% [markdown]
# ## 1048.

# %% [markdown]
# ## 1049.

# %% [markdown]
# ## 1050.

# %% [markdown]
# ## 1051.

# %% [markdown]
# ## 1052.

# %% [markdown]
# ## 1053.

# %% [markdown]
# ## 1054.

# %% [markdown]
# ## 1055.

# %% [markdown]
# ## 1056.

# %% [markdown]
# ## 1057.

# %% [markdown]
# ## 1058.

# %% [markdown]
# ## 1059.

# %% [markdown]
# ## 1060.

# %% [markdown]
# ## 1061.

# %% [markdown]
# ## 1062.

# %% [markdown]
# ## 1063.

# %% [markdown]
# ## 1064.

# %% [markdown]
# ## 1065.

# %% [markdown]
# ## 1066.

# %% [markdown]
# ## 1067.

# %% [markdown]
# ## 1068.

# %% [markdown]
# ## 1069.

# %% [markdown]
# ## 1070.

# %% [markdown]
# ## 1071.

# %% [markdown]
# ## 1072.

# %% [markdown]
# ## 1073.

# %% [markdown]
# ## 1074.

# %% [markdown]
# ## 1075.

# %% [markdown]
# ## 1076.

# %% [markdown]
# ## 1077.

# %% [markdown]
# ## 1078.

# %% [markdown]
# ## 1079.

# %% [markdown]
# ## 1080.

# %% [markdown]
# ## 1081.

# %% [markdown]
# ## 1082.

# %% [markdown]
# ## 1083.

# %% [markdown]
# ## 1084.

# %% [markdown]
# ## 1085.

# %% [markdown]
# ## 1086.

# %% [markdown]
# ## 1087.

# %% [markdown]
# ## 1088.

# %% [markdown]
# ## 1089.

# %% [markdown]
# ## 1090.

# %% [markdown]
# ## 1091.

# %% [markdown]
# ## 1092.

# %% [markdown]
# ## 1093.

# %% [markdown]
# ## 1094.

# %% [markdown]
# ## 1095.

# %% [markdown]
# ## 1096.

# %% [markdown]
# ## 1097.

# %% [markdown]
# ## 1098.

# %% [markdown]
# ## 1099.

# %% [markdown]
# ## 1100.

# %% [markdown]
# ## 1101.

# %% [markdown]
# ## 1102.

# %% [markdown]
# ## 1103.

# %% [markdown]
# ## 1104.

# %% [markdown]
# ## 1105.

# %% [markdown]
# ## 1106.

# %% [markdown]
# ## 1107.

# %% [markdown]
# ## 1108.

# %% [markdown]
# ## 1109.

# %% [markdown]
# ## 1110.

# %% [markdown]
# ## 1111.

# %% [markdown]
# ## 1112.

# %% [markdown]
# ## 1113.

# %% [markdown]
# ## 1114.

# %% [markdown]
# ## 1115.

# %% [markdown]
# ## 1116.

# %% [markdown]
# ## 1117.

# %% [markdown]
# ## 1118.

# %% [markdown]
# ## 1119.

# %% [markdown]
# ## 1120.

# %% [markdown]
# ## 1121.

# %% [markdown]
# ## 1122.

# %% [markdown]
# ## 1123.

# %% [markdown]
# ## 1124.

# %% [markdown]
# ## 1125.

# %% [markdown]
# ## 1126.

# %% [markdown]
# ## 1127.

# %% [markdown]
# ## 1128.

# %% [markdown]
# ## 1129.

# %% [markdown]
# ## 1130.

# %% [markdown]
# ## 1131.

# %% [markdown]
# ## 1132.

# %% [markdown]
# ## 1133.

# %% [markdown]
# ## 1134.

# %% [markdown]
# ## 1135.

# %% [markdown]
# ## 1136.

# %% [markdown]
# ## 1137.

# %% [markdown]
# ## 1138.

# %% [markdown]
# ## 1139.

# %% [markdown]
# ## 1140.

# %% [markdown]
# ## 1141.

# %% [markdown]
# ## 1142.

# %% [markdown]
# ## 1143.

# %% [markdown]
# ## 1144.

# %% [markdown]
# ## 1145.

# %% [markdown]
# ## 1146.

# %% [markdown]
# ## 1147.

# %% [markdown]
# ## 1148.

# %% [markdown]
# ## 1149.

# %% [markdown]
# ## 1150.

# %% [markdown]
# ## 1151.

# %% [markdown]
# ## 1152.

# %% [markdown]
# ## 1153.

# %% [markdown]
# ## 1154.

# %% [markdown]
# ## 1155.

# %% [markdown]
# ## 1156.

# %% [markdown]
# ## 1157.

# %% [markdown]
# ## 1158.

# %% [markdown]
# ## 1159.

# %% [markdown]
# ## 1160.

# %% [markdown]
# ## 1161.

# %% [markdown]
# ## 1162.

# %% [markdown]
# ## 1163.

# %% [markdown]
# ## 1164.

# %% [markdown]
# ## 1165.

# %% [markdown]
# ## 1166.

# %% [markdown]
# ## 1167.

# %% [markdown]
# ## 1168.

# %% [markdown]
# ## 1169.

# %% [markdown]
# ## 1170.

# %% [markdown]
# ## 1171.

# %% [markdown]
# ## 1172.

# %% [markdown]
# ## 1173.

# %% [markdown]
# ## 1174.

# %% [markdown]
# ## 1175.

# %% [markdown]
# ## 1176.

# %% [markdown]
# ## 1177.

# %% [markdown]
# ## 1178.

# %% [markdown]
# ## 1179.

# %% [markdown]
# ## 1180.

# %% [markdown]
# ## 1181.

# %% [markdown]
# ## 1182.

# %% [markdown]
# ## 1183.

# %% [markdown]
# ## 1184.

# %% [markdown]
# ## 1185.

# %% [markdown]
# ## 1186.

# %% [markdown]
# ## 1187.

# %% [markdown]
# ## 1188.

# %% [markdown]
# ## 1189.

# %% [markdown]
# ## 1190.

# %% [markdown]
# ## 1191.

# %% [markdown]
# ## 1192.

# %% [markdown]
# ## 1193.

# %% [markdown]
# ## 1194.

# %% [markdown]
# ## 1195.

# %% [markdown]
# ## 1196.

# %% [markdown]
# ## 1197.

# %% [markdown]
# ## 1198.

# %% [markdown]
# ## 1199.

# %% [markdown]
# ## 200.
