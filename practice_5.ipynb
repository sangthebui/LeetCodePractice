# %% [markdown]
# # Practice 5
# - More LeetCode Questions

# %% [markdown]
# ## 801.

# %% [markdown]
# ## 802.

# %% [markdown]
# ## 803.

# %% [markdown]
# ## 804.

# %% [markdown]
# ## 805.

# %% [markdown]
# ## 806.

# %% [markdown]
# ## 807.

# %% [markdown]
# ## 808.

# %% [markdown]
# ## 809.

# %% [markdown]
# ## 810.

# %% [markdown]
# ## 811.

# %% [markdown]
# ## 812.

# %% [markdown]
# ## 813.

# %% [markdown]
# ## 814.

# %% [markdown]
# ## 815.

# %% [markdown]
# ## 816.

# %% [markdown]
# ## 817.

# %% [markdown]
# ## 818.

# %% [markdown]
# ## 819.

# %% [markdown]
# ## 820.

# %% [markdown]
# ## 821.

# %% [markdown]
# ## 822.

# %% [markdown]
# ## 823.

# %% [markdown]
# ## 824.

# %% [markdown]
# ## 825.

# %% [markdown]
# ## 826.

# %% [markdown]
# ## 827.

# %% [markdown]
# ## 828.

# %% [markdown]
# ## 829.

# %% [markdown]
# ## 830.

# %% [markdown]
# ## 831.

# %% [markdown]
# ## 832.

# %% [markdown]
# ## 833.

# %% [markdown]
# ## 834.

# %% [markdown]
# ## 835.

# %% [markdown]
# ## 836.

# %% [markdown]
# ## 837.

# %% [markdown]
# ## 838.

# %% [markdown]
# ## 839.

# %% [markdown]
# ## 840.

# %% [markdown]
# ## 841.

# %% [markdown]
# ## 842.

# %% [markdown]
# ## 843.

# %% [markdown]
# ## 844.

# %% [markdown]
# ## 845.

# %% [markdown]
# ## 846.

# %% [markdown]
# ## 847.

# %% [markdown]
# ## 848.

# %% [markdown]
# ## 849.

# %% [markdown]
# ## 850.

# %% [markdown]
# ## 851.

# %% [markdown]
# ## 852.

# %% [markdown]
# ## 853.

# %% [markdown]
# ## 854.

# %% [markdown]
# ## 856.

# %% [markdown]
# ## 857.

# %% [markdown]
# ## 858.

# %% [markdown]
# ## 859.

# %% [markdown]
# ## 860.

# %% [markdown]
# ## 861.

# %% [markdown]
# ## 862.

# %% [markdown]
# ## 863.

# %% [markdown]
# ## 864.

# %% [markdown]
# ## 865.

# %% [markdown]
# ## 866.

# %% [markdown]
# ## 867.

# %% [markdown]
# ## 868.

# %% [markdown]
# ## 869.

# %% [markdown]
# ## 870.

# %% [markdown]
# ## 871.

# %% [markdown]
# ## 872.

# %% [markdown]
# ## 873.

# %% [markdown]
# ## 874.

# %% [markdown]
# ## 875.

# %% [markdown]
# ## 876.

# %% [markdown]
# ## 877.

# %% [markdown]
# ## 878.

# %% [markdown]
# ## 879.

# %% [markdown]
# ## 880.

# %% [markdown]
# ## 881.

# %% [markdown]
# ## 882.

# %% [markdown]
# ## 883.

# %% [markdown]
# ## 884.

# %% [markdown]
# ## 885.

# %% [markdown]
# ## 886.

# %% [markdown]
# ## 887.

# %% [markdown]
# ## 888.

# %% [markdown]
# ## 889.

# %% [markdown]
# ## 890.

# %% [markdown]
# ## 891.

# %% [markdown]
# ## 892.

# %% [markdown]
# ## 893.

# %% [markdown]
# ## 894.

# %% [markdown]
# ## 895.

# %% [markdown]
# ## 896.

# %% [markdown]
# ## 897.

# %% [markdown]
# ## 898.

# %% [markdown]
# ## 899.

# %% [markdown]
# ## 900.

# %% [markdown]
# ## 901.

# %% [markdown]
# ## 902.

# %% [markdown]
# ## 903.

# %% [markdown]
# ## 904.

# %% [markdown]
# ## 905.

# %% [markdown]
# ## 906.

# %% [markdown]
# ## 907.

# %% [markdown]
# ## 908.

# %% [markdown]
# ## 909.

# %% [markdown]
# ## 910.

# %% [markdown]
# ## 911.

# %% [markdown]
# ## 912.

# %% [markdown]
# ## 913.

# %% [markdown]
# ## 914.

# %% [markdown]
# ## 915.

# %% [markdown]
# ## 916.

# %% [markdown]
# ## 917.

# %% [markdown]
# ## 918.

# %% [markdown]
# ## 919.

# %% [markdown]
# ## 920.

# %% [markdown]
# ## 921.

# %% [markdown]
# ## 922.

# %% [markdown]
# ## 923.

# %% [markdown]
# ## 924.

# %% [markdown]
# ## 925.

# %% [markdown]
# ## 926.

# %% [markdown]
# ## 927.

# %% [markdown]
# ## 928.

# %% [markdown]
# ## 929.

# %% [markdown]
# ## 930.

# %% [markdown]
# ## 931.

# %% [markdown]
# ## 932.

# %% [markdown]
# ## 933.

# %% [markdown]
# ## 934.

# %% [markdown]
# ## 935.

# %% [markdown]
# ## 934.

# %% [markdown]
# ## 935.

# %% [markdown]
# ## 936.

# %% [markdown]
# ## 937.

# %% [markdown]
# ## 938.

# %% [markdown]
# ## 939.

# %% [markdown]
# ## 940.

# %% [markdown]
# ## 941.

# %% [markdown]
# ## 942.

# %% [markdown]
# ## 943.

# %% [markdown]
# ## 944.

# %% [markdown]
# ## 945.

# %% [markdown]
# ## 946.

# %% [markdown]
# ## 947.

# %% [markdown]
# ## 948.

# %% [markdown]
# ## 949.

# %% [markdown]
# ## 950.

# %% [markdown]
# ## 951.

# %% [markdown]
# ## 952.

# %% [markdown]
# ## 953.

# %% [markdown]
# ## 954.

# %% [markdown]
# ## 955.

# %% [markdown]
# ## 956.

# %% [markdown]
# ## 957.

# %% [markdown]
# ## 958.

# %% [markdown]
# ## 959.

# %% [markdown]
# ## 960.

# %% [markdown]
# ## 961.

# %% [markdown]
# ## 962.

# %% [markdown]
# ## 963.

# %% [markdown]
# ## 964.

# %% [markdown]
# ## 965.

# %% [markdown]
# ## 966.

# %% [markdown]
# ## 967.

# %% [markdown]
# ## 968.

# %% [markdown]
# ## 969.

# %% [markdown]
# ## 970.

# %% [markdown]
# ## 971.

# %% [markdown]
# ## 972.

# %% [markdown]
# ## 973.

# %% [markdown]
# ## 974.

# %% [markdown]
# ## 975.

# %% [markdown]
# ## 976.

# %% [markdown]
# ## 977.

# %% [markdown]
# ## 978.

# %% [markdown]
# ## 979.

# %% [markdown]
# ## 980.

# %% [markdown]
# ## 981.

# %% [markdown]
# ## 982.

# %% [markdown]
# ## 983.

# %% [markdown]
# ## 984.

# %% [markdown]
# ## 985.

# %% [markdown]
# ## 986.

# %% [markdown]
# ## 987.

# %% [markdown]
# ## 988.

# %% [markdown]
# ## 989.

# %% [markdown]
# ## 990.

# %% [markdown]
# ## 991.

# %% [markdown]
# ## 992.

# %% [markdown]
# ## 993.

# %% [markdown]
# ## 994.

# %% [markdown]
# ## 995.

# %% [markdown]
# ## 996.

# %% [markdown]
# ## 997.

# %% [markdown]
# ## 998.

# %% [markdown]
# ## 999.

# %% [markdown]
# ## 1000
