# %% [markdown]
# # Practice 7
# - More LeetCode Questions

# %% [markdown]
# ## 1201.

# %% [markdown]
# ## 1202.

# %% [markdown]
# ## 1203.

# %% [markdown]
# ## 1204.

# %% [markdown]
# ## 1205.

# %% [markdown]
# ## 1206.

# %% [markdown]
# ## 1207.

# %% [markdown]
# ## 1208.

# %% [markdown]
# ## 1209.

# %% [markdown]
# ## 1210.

# %% [markdown]
# ## 1211.

# %% [markdown]
# ## 1212.

# %% [markdown]
# ## 1213.

# %% [markdown]
# ## 1214.

# %% [markdown]
# ## 1215.

# %% [markdown]
# ## 1216.

# %% [markdown]
# ## 1217.

# %% [markdown]
# ## 1218.

# %% [markdown]
# ## 1219.

# %% [markdown]
# ## 1220.

# %% [markdown]
# ## 1221.

# %% [markdown]
# ## 1222.

# %% [markdown]
# ## 1223.

# %% [markdown]
# ## 1224.

# %% [markdown]
# ## 1225.

# %% [markdown]
# ##  1226.

# %% [markdown]
# ## 1227.

# %% [markdown]
# ## 1228.

# %% [markdown]
# ## 1229.

# %% [markdown]
# ## 1230.

# %% [markdown]
# ## 1231.

# %% [markdown]
# ## 1232.

# %% [markdown]
# ## 1233.

# %% [markdown]
# ## 1234.

# %% [markdown]
# ## 1235.

# %% [markdown]
# ## 1236.

# %% [markdown]
# ## 1237.

# %% [markdown]
# ## 1238.

# %% [markdown]
# ## 1239.

# %% [markdown]
# ## 1240.

# %% [markdown]
# ## 1241.

# %% [markdown]
# ## 1242.

# %% [markdown]
# ## 1243.

# %% [markdown]
# ## 1244.

# %% [markdown]
# ## 1245.

# %% [markdown]
# ## 1246.

# %% [markdown]
# ## 1247.

# %% [markdown]
# ## 1248.

# %% [markdown]
# ## 1249.

# %% [markdown]
# ## 1250.

# %% [markdown]
# ## 1251.

# %% [markdown]
# ## 1252.

# %% [markdown]
# ## 1253.

# %% [markdown]
# ## 1254.

# %% [markdown]
# ## 1255.

# %% [markdown]
# ## 1256.

# %% [markdown]
# ## 1257.

# %% [markdown]
# ## 1258.

# %% [markdown]
# ## 1259.

# %% [markdown]
# ## 1260.

# %% [markdown]
# ## 1261.

# %% [markdown]
# ## 1262.

# %% [markdown]
# ## 1263.

# %% [markdown]
# ## 1264.

# %% [markdown]
# ## 1265.

# %% [markdown]
# ## 1266.

# %% [markdown]
# ## 1267.

# %% [markdown]
# ## 1268.

# %% [markdown]
# ## 1269.

# %% [markdown]
# ## 1270.

# %% [markdown]
# ## 1271.

# %% [markdown]
# ## 1272.

# %% [markdown]
# ## 1273.

# %% [markdown]
# ## 1274.

# %% [markdown]
# ## 1275.

# %% [markdown]
# ## 1276.

# %% [markdown]
# ## 1277.

# %% [markdown]
# ## 1278.

# %% [markdown]
# ## 1279.

# %% [markdown]
# ## 1280.

# %% [markdown]
# ## 1281.

# %% [markdown]
# ## 1282.

# %% [markdown]
# ## 1283.

# %% [markdown]
# ## 1284.

# %% [markdown]
# ## 1285.

# %% [markdown]
# ## 1286.

# %% [markdown]
# ## 1287.

# %% [markdown]
# ## 1288.

# %% [markdown]
# ## 1289.

# %% [markdown]
# ## 1290.

# %% [markdown]
# ## 1291.

# %% [markdown]
# ## 1292.

# %% [markdown]
# ## 1293.

# %% [markdown]
# ## 1294.

# %% [markdown]
# ## 1295.

# %% [markdown]
# ## 1296.

# %% [markdown]
# ## 1297.

# %% [markdown]
# ## 1298.

# %% [markdown]
# ## 1299.

# %% [markdown]
# ## 1300.

# %% [markdown]
# ## 1301.

# %% [markdown]
# ## 1302.

# %% [markdown]
# ## 1303.

# %% [markdown]
# ## 1304.

# %% [markdown]
# ## 1305.

# %% [markdown]
# ## 1306.

# %% [markdown]
# ## 1307.

# %% [markdown]
# ## 1308.

# %% [markdown]
# ## 1309.

# %% [markdown]
# ## 1310.

# %% [markdown]
# ## 1311.

# %% [markdown]
# ## 1312.

# %% [markdown]
# ## 1313.

# %% [markdown]
# ## 1314.

# %% [markdown]
# ## 1315.

# %% [markdown]
# ## 1316.

# %% [markdown]
# ## 1317.

# %% [markdown]
# ## 1318.

# %% [markdown]
# ## 1319.

# %% [markdown]
# ## 1320.

# %% [markdown]
# ## 1321.

# %% [markdown]
# ## 1322.

# %% [markdown]
# ## 1323.

# %% [markdown]
# ## 1324.

# %% [markdown]
# ## 1325.

# %% [markdown]
# ## 1326.

# %% [markdown]
# ## 1327.

# %% [markdown]
# ## 1328.

# %% [markdown]
# ## 1329.

# %% [markdown]
# ## 1330.

# %% [markdown]
# ## 1331.

# %% [markdown]
# ## 1332.

# %% [markdown]
# ## 1333.

# %% [markdown]
# ## 1334.

# %% [markdown]
# ## 1335.

# %% [markdown]
# ## 1336.

# %% [markdown]
# ## 1337.

# %% [markdown]
# ## 1338.

# %% [markdown]
# ## 1339.

# %% [markdown]
# ## 1340.

# %% [markdown]
# ## 1341.

# %% [markdown]
# ## 1342.

# %% [markdown]
# ## 1343.

# %% [markdown]
# ## 1344.

# %% [markdown]
# ## 1345.

# %% [markdown]
# ## 1346.

# %% [markdown]
# ## 1347.

# %% [markdown]
# ## 1348.

# %% [markdown]
# ## 1349.

# %% [markdown]
# ## 1350.

# %% [markdown]
# ## 1351.

# %% [markdown]
# ## 1352.

# %% [markdown]
# ## 1353.

# %% [markdown]
# ## 1354.

# %% [markdown]
# ## 1355.

# %% [markdown]
# ## 1356.

# %% [markdown]
# ## 1357.

# %% [markdown]
# ## 1358.

# %% [markdown]
# ## 1359.

# %% [markdown]
# ## 1360.

# %% [markdown]
# ## 1361.

# %% [markdown]
# ## 1362.

# %% [markdown]
# ## 1363.

# %% [markdown]
# ## 1364.

# %% [markdown]
# ## 1365.

# %% [markdown]
# ## 1366.

# %% [markdown]
# ## 1367.

# %% [markdown]
# ## 1368.

# %% [markdown]
# ## 1369.

# %% [markdown]
# ## 1370.

# %% [markdown]
# ## 1371.

# %% [markdown]
# ## 1372.

# %% [markdown]
# ## 1373.

# %% [markdown]
# ## 1374.

# %% [markdown]
# ## 1375.

# %% [markdown]
# ## 1376.

# %% [markdown]
# ## 1377.

# %% [markdown]
# ## 1378.

# %% [markdown]
# ## 1379.

# %% [markdown]
# ## 1380.

# %% [markdown]
# ## 1381.

# %% [markdown]
# ## 1382.

# %% [markdown]
# ## 1383.

# %% [markdown]
# ## 1384.

# %% [markdown]
# ## 1385.

# %% [markdown]
# ## 1386.

# %% [markdown]
# ## 1387.

# %% [markdown]
# ## 1388.

# %% [markdown]
# ## 1389.

# %% [markdown]
# ## 1390.

# %% [markdown]
# ## 1391.

# %% [markdown]
# ## 1392.

# %% [markdown]
# ## 1393.

# %% [markdown]
# ##  1394.

# %% [markdown]
# ## 1395.

# %% [markdown]
# ## 1396.

# %% [markdown]
# ## 1397.

# %% [markdown]
# ## 1398.

# %% [markdown]
# ## 1399.

# %% [markdown]
# ## 1400.
