# %% [markdown]
# # Practice 9
# - More LeetCode Practice

# %% [markdown]
# ## 1601.

# %% [markdown]
# ## 1602.

# %% [markdown]
# ## 1603.

# %% [markdown]
# ## 1604.

# %% [markdown]
# ## 1605.

# %% [markdown]
# ## 1606.

# %% [markdown]
# ## 1607.

# %% [markdown]
# ## 1608.

# %% [markdown]
# ## 1609.

# %% [markdown]
# ## 1610.

# %% [markdown]
# ## 1611.

# %% [markdown]
# ## 1612.

# %% [markdown]
# ## 1613.

# %% [markdown]
# ## 1614.

# %% [markdown]
# ## 1615.

# %% [markdown]
# ## 1617.

# %% [markdown]
# ## 1618.

# %% [markdown]
# ## 1619.

# %% [markdown]
# ## 1620.

# %% [markdown]
# ## 1621.

# %% [markdown]
# ## 1622.

# %% [markdown]
# ## 1623.

# %% [markdown]
# ## 1624.

# %% [markdown]
# ## 1625.

# %% [markdown]
# ## 1626.

# %% [markdown]
# ## 1627.

# %% [markdown]
# ## 1628.

# %% [markdown]
# ## 1629.

# %% [markdown]
# ## 1630.

# %% [markdown]
# ## 1631.

# %% [markdown]
# ## 1632.

# %% [markdown]
# ## 1633.

# %% [markdown]
# ## 1634.

# %% [markdown]
# ## 1635.

# %% [markdown]
# ## 1636.

# %% [markdown]
# ## 1637.

# %% [markdown]
# ## 1638.

# %% [markdown]
# ## 1639.

# %% [markdown]
# ## 1640.

# %% [markdown]
# ## 1641.

# %% [markdown]
# ## 1642.

# %% [markdown]
# ## 1643.

# %% [markdown]
# ## 1644.

# %% [markdown]
# ## 1645.

# %% [markdown]
# ## 1646.

# %% [markdown]
# ## 1647.

# %% [markdown]
# ## 1648.

# %% [markdown]
# ## 1649.

# %% [markdown]
# ## 1650.

# %% [markdown]
# ## 1651.

# %% [markdown]
# ## 1652.

# %% [markdown]
# ## 1653.

# %% [markdown]
# ## 1654.

# %% [markdown]
# ## 1655.

# %% [markdown]
# ## 1656.

# %% [markdown]
# ## 1657.

# %% [markdown]
# ## 1658.

# %% [markdown]
# ## 1659.

# %% [markdown]
# ## 1660.

# %% [markdown]
# ## 1661.

# %% [markdown]
# ## 1662.

# %% [markdown]
# ## 1663.

# %% [markdown]
# ## 1664.

# %% [markdown]
# ## 1665.

# %% [markdown]
# ## 1666.

# %% [markdown]
# ## 1667.

# %% [markdown]
# ## 1668.

# %% [markdown]
# ## 1669.

# %% [markdown]
# ## 1670.

# %% [markdown]
# ## 1671.

# %% [markdown]
# ## 1672.

# %% [markdown]
# ## 1673.

# %% [markdown]
# ## 1674.

# %% [markdown]
# ## 1675.

# %% [markdown]
# ## 1676.

# %% [markdown]
# ## 1678.

# %% [markdown]
# ## 1679.

# %% [markdown]
# ## 1680.

# %% [markdown]
# ## 1681.

# %% [markdown]
# ## 1682.

# %% [markdown]
# ## 1683.

# %% [markdown]
# ## 1684.

# %% [markdown]
# ## 1685.

# %% [markdown]
# ## 1686.

# %% [markdown]
# ## 1687.

# %% [markdown]
# ## 1688.

# %% [markdown]
# ## 1689.

# %% [markdown]
# ## 1690.

# %% [markdown]
# ## 1691.

# %% [markdown]
# ## 1692.

# %% [markdown]
# ## 1693.

# %% [markdown]
# ## 1694.

# %% [markdown]
# ## 1695.

# %% [markdown]
# ## 1696.

# %% [markdown]
# ## 1697.

# %% [markdown]
# ## 1698.

# %% [markdown]
# ## 1699.

# %% [markdown]
# ## 1700.

# %% [markdown]
# ## 1701.

# %% [markdown]
# ## 1702.

# %% [markdown]
# ## 1703.

# %% [markdown]
# ## 1704.

# %% [markdown]
# ## 1705.

# %% [markdown]
# ## 1706.

# %% [markdown]
# ## 1707.

# %% [markdown]
# ## 1708.

# %% [markdown]
# ## 1709.

# %% [markdown]
# ## 1710.

# %% [markdown]
# ## 1711.

# %% [markdown]
# ## 1712.

# %% [markdown]
# ## 1713.

# %% [markdown]
# ## 1714.

# %% [markdown]
# ## 1715.

# %% [markdown]
# ## 1716.

# %% [markdown]
# ## 1717.

# %% [markdown]
# ## 1718.

# %% [markdown]
# ## 1719.

# %% [markdown]
# ## 1720.

# %% [markdown]
# ## 1721.

# %% [markdown]
# ## 1722.

# %% [markdown]
# ## 1723.

# %% [markdown]
# ## 1724.

# %% [markdown]
# ## 1725.

# %% [markdown]
# ## 1726.

# %% [markdown]
# ## 1727.

# %% [markdown]
# ## 1728.

# %% [markdown]
# ## 1729.

# %% [markdown]
# ## 1730.

# %% [markdown]
# ## 1731.

# %% [markdown]
# ## 1732.

# %% [markdown]
# ## 1733.

# %% [markdown]
# ## 1734.

# %% [markdown]
# ## 1735.

# %% [markdown]
# ## 1736.

# %% [markdown]
# ## 1737.

# %% [markdown]
# ## 1738.

# %% [markdown]
# ## 1739.

# %% [markdown]
# ## 1740.

# %% [markdown]
# ## 1741.

# %% [markdown]
# ## 1742.

# %% [markdown]
# ## 1743.

# %% [markdown]
# ## 1744.

# %% [markdown]
# ## 1745.

# %% [markdown]
# ## 1746.

# %% [markdown]
# ## 1747.

# %% [markdown]
# ## 1748.

# %% [markdown]
# ## 1749.

# %% [markdown]
# ## 1750.

# %% [markdown]
# ## 1751.

# %% [markdown]
# ## 1752.

# %% [markdown]
# ## 1753.

# %% [markdown]
# ## 1754.

# %% [markdown]
# ## 1755.

# %% [markdown]
# ## 1756.

# %% [markdown]
# ## 1757.

# %% [markdown]
# ## 1758.

# %% [markdown]
# ## 1759.

# %% [markdown]
# ## 1760.

# %% [markdown]
# ## 1761.

# %% [markdown]
# ## 1762.

# %% [markdown]
# ## 1763.

# %% [markdown]
# ## 1764.

# %% [markdown]
# ## 1765.

# %% [markdown]
# ## 1766.

# %% [markdown]
# ## 1767.

# %% [markdown]
# ## 1768.

# %% [markdown]
# ## 1769.

# %% [markdown]
# ## 1770.

# %% [markdown]
# ## 1771.

# %% [markdown]
# ## 1772.

# %% [markdown]
# ## 1773.

# %% [markdown]
# ## 1774.

# %% [markdown]
# ## 1775.

# %% [markdown]
# ## 1776.

# %% [markdown]
# ## 1777.

# %% [markdown]
# ## 1778.

# %% [markdown]
# ## 1779.

# %% [markdown]
# ## 1780.

# %% [markdown]
# ## 1781.

# %% [markdown]
# ## 1782.

# %% [markdown]
# ## 1783.

# %% [markdown]
# ## 1784.

# %% [markdown]
# ## 1785.

# %% [markdown]
# ## 1786.

# %% [markdown]
# ## 1787.

# %% [markdown]
# ## 1788.

# %% [markdown]
# ## 1789.

# %% [markdown]
# ## 1790.

# %% [markdown]
# ## 1791.

# %% [markdown]
# ## 1792.

# %% [markdown]
# ## 1793.

# %% [markdown]
# ## 1794.

# %% [markdown]
# ## 1795.

# %% [markdown]
# ## 1796.

# %% [markdown]
# ## 1797.

# %% [markdown]
# ## 1798.

# %% [markdown]
# ## 1799.

# %% [markdown]
# ## 1800.
