# %% [markdown]
# # Practice 8.
# - More LeetCode Questions

# %% [markdown]
# ## 1401.

# %% [markdown]
# ## 1402.

# %% [markdown]
# ## 1403.

# %% [markdown]
# ## 1404.

# %% [markdown]
# ## 1405.

# %% [markdown]
# ## 1406.

# %% [markdown]
# ## 1407.

# %% [markdown]
# ## 1408.

# %% [markdown]
# ## 1409.

# %% [markdown]
# ## 1410.

# %% [markdown]
# ## 1411.

# %% [markdown]
# ## 1412.

# %% [markdown]
# ## 1413.

# %% [markdown]
# ## 1415.

# %% [markdown]
# ## 1416.

# %% [markdown]
# ## 1417.

# %% [markdown]
# ## 1418.

# %% [markdown]
# ## 1419.

# %% [markdown]
# ## 1420.

# %% [markdown]
# ## 1421.

# %% [markdown]
# ## 1422.

# %% [markdown]
# ## 1423.

# %% [markdown]
# ## 1424.

# %% [markdown]
# ## 1425.

# %% [markdown]
# ## 1426.

# %% [markdown]
# ## 1427.

# %% [markdown]
# ## 1428.

# %% [markdown]
# ## 1429.

# %% [markdown]
# ## 1430.

# %% [markdown]
# ## 1431.

# %% [markdown]
# ## 1432.

# %% [markdown]
# ## 1433.

# %% [markdown]
# ## 1434.

# %% [markdown]
# ## 1435.

# %% [markdown]
# ## 1436.

# %% [markdown]
# ## 1437.

# %% [markdown]
# ## 1438.

# %% [markdown]
# ## 1439.

# %% [markdown]
# ## 1440.

# %% [markdown]
# ## 1441.

# %% [markdown]
# ## 1442.

# %% [markdown]
# ## 1443.

# %% [markdown]
# ## 1444.

# %% [markdown]
# ## 1445.

# %% [markdown]
# ## 1446.

# %% [markdown]
# ## 1447.

# %% [markdown]
# ## 1448.

# %% [markdown]
# ## 1449.

# %% [markdown]
# ## 1450.

# %% [markdown]
# ## 1451.

# %% [markdown]
# ## 1452.

# %% [markdown]
# ## 1453.

# %% [markdown]
# ## 1454.

# %% [markdown]
# ## 1455.

# %% [markdown]
# ## 1456.

# %% [markdown]
# ## 1457.

# %% [markdown]
# ## 1458.

# %% [markdown]
# ## 1459.

# %% [markdown]
# ## 1460.

# %% [markdown]
# ## 1461.

# %% [markdown]
# ## 1462.

# %% [markdown]
# ## 1463.

# %% [markdown]
# ## 1464.

# %% [markdown]
# ## 1465.

# %% [markdown]
# ## 1466.

# %% [markdown]
# ## 1467.

# %% [markdown]
# ## 1468.

# %% [markdown]
# ## 1469.

# %% [markdown]
# ## 1470.

# %% [markdown]
# ## 1471.

# %% [markdown]
# ## 1472.

# %% [markdown]
# ## 1473.

# %% [markdown]
# ## 1474.

# %% [markdown]
# ## 1475.

# %% [markdown]
# ## 1476.

# %% [markdown]
# ## 1477.

# %% [markdown]
# ## 1478.

# %% [markdown]
# ## 1479.

# %% [markdown]
# ## 1480.

# %% [markdown]
# ## 1481.

# %% [markdown]
# ## 1482.

# %% [markdown]
# ## 1483.

# %% [markdown]
# ## 1484.

# %% [markdown]
# ## 1485.

# %% [markdown]
# ## 1486.

# %% [markdown]
# ## 1487.

# %% [markdown]
# ## 1488.

# %% [markdown]
# ## 1489.

# %% [markdown]
# ## 1490.

# %% [markdown]
# ## 1491.

# %% [markdown]
# ## 1492.

# %% [markdown]
# ## 1493.

# %% [markdown]
# ## 1494.

# %% [markdown]
# ## 1495.

# %% [markdown]
# ## 1496.

# %% [markdown]
# ## 1497.

# %% [markdown]
# ## 1498.

# %% [markdown]
# ## 1499.

# %% [markdown]
# ## 1500.

# %% [markdown]
# ## 1501.

# %% [markdown]
# ## 1502.

# %% [markdown]
# ## 1503.

# %% [markdown]
# ## 1504.

# %% [markdown]
# ## 1505.

# %% [markdown]
# ## 1506.

# %% [markdown]
# ## 1507.

# %% [markdown]
# ## 1508.

# %% [markdown]
# ## 1509.

# %% [markdown]
# ## 1510.

# %% [markdown]
# ## 1511.

# %% [markdown]
# ## 1512.

# %% [markdown]
# ## 1513.

# %% [markdown]
# ## 1514.

# %% [markdown]
# ## 1515.

# %% [markdown]
# ## 1516.

# %% [markdown]
# ## 1517.

# %% [markdown]
# ## 1518.

# %% [markdown]
# ## 1519.

# %% [markdown]
# ## 1520.

# %% [markdown]
# ## 1521.

# %% [markdown]
# ## 1522.

# %% [markdown]
# ## 1523.

# %% [markdown]
# ## 1524.

# %% [markdown]
# ## 1525.

# %% [markdown]
# ## 1526.

# %% [markdown]
# ## 1527.

# %% [markdown]
# ## 1528.

# %% [markdown]
# ## 1529.

# %% [markdown]
# ## 1530.

# %% [markdown]
# ## 1531.

# %% [markdown]
# ## 1532.

# %% [markdown]
# ## 1533.

# %% [markdown]
# ## 1534.

# %% [markdown]
# ## 1535.

# %% [markdown]
# ## 1536.

# %% [markdown]
# ## 1537.

# %% [markdown]
# ## 1538.

# %% [markdown]
# ## 1539.

# %% [markdown]
# ## 1540.

# %% [markdown]
# ## 1541.

# %% [markdown]
# ## 1542.

# %% [markdown]
# ## 1543.

# %% [markdown]
# ## 1544.

# %% [markdown]
# ## 1545.

# %% [markdown]
# ## 1546.

# %% [markdown]
# ## 1547.

# %% [markdown]
# ## 1548.

# %% [markdown]
# ## 1549.

# %% [markdown]
# ## 1550.

# %% [markdown]
# ## 1551.

# %% [markdown]
# ## 1552.

# %% [markdown]
# ## 1553.

# %% [markdown]
# ## 1554.

# %% [markdown]
# ## 1555.

# %% [markdown]
# ## 1556.

# %% [markdown]
# ## 1557.

# %% [markdown]
# ## 1558.

# %% [markdown]
# ## 1559.

# %% [markdown]
# ## 1560.

# %% [markdown]
# ## 1561.

# %% [markdown]
# ## 1562.

# %% [markdown]
# ## 1563.

# %% [markdown]
# ## 1564.

# %% [markdown]
# ## 1565.

# %% [markdown]
# ## 1566.

# %% [markdown]
# ## 1567.

# %% [markdown]
# ## 1568.

# %% [markdown]
# ## 1569.

# %% [markdown]
# ## 1570.

# %% [markdown]
# ## 1571.

# %% [markdown]
# ## 1572.

# %% [markdown]
# ## 1573.

# %% [markdown]
# ## 1574.

# %% [markdown]
# ## 1575.

# %% [markdown]
# ## 1576.

# %% [markdown]
# ## 1577.

# %% [markdown]
# ## 1578.

# %% [markdown]
# ## 1579.

# %% [markdown]
# ## 1580.

# %% [markdown]
# ## 1581.

# %% [markdown]
# ## 1582.

# %% [markdown]
# ## 1583.

# %% [markdown]
# ## 1584.

# %% [markdown]
# ## 1585.

# %% [markdown]
# ## 1586.

# %% [markdown]
# ## 1587.

# %% [markdown]
# ## 1588.

# %% [markdown]
# ## 1589.

# %% [markdown]
# ## 1590.

# %% [markdown]
# ## 1591.

# %% [markdown]
# ## 1592.

# %% [markdown]
# ## 1593.

# %% [markdown]
# ## 1594.

# %% [markdown]
# ## 1595.

# %% [markdown]
# ## 1596.

# %% [markdown]
# ## 1597.

# %% [markdown]
# ## 1598.

# %% [markdown]
# ## 1599.

# %% [markdown]
# ## 1600.
