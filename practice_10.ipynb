# %% [markdown]
# # Practice 10.
# - More LeetCode Questions

# %% [markdown]
# ## 1801.

# %% [markdown]
# ## 1802.

# %% [markdown]
# ## 1803.

# %% [markdown]
# ## 1804.

# %% [markdown]
# ## 1805.

# %% [markdown]
# ## 1806.

# %% [markdown]
# ## 1807.

# %% [markdown]
# ## 1808.

# %% [markdown]
# ## 1809.

# %% [markdown]
# ## 1810.

# %% [markdown]
# ## 1811.

# %% [markdown]
# ## 1812.

# %% [markdown]
# ## 1813.

# %% [markdown]
# ## 1814.

# %% [markdown]
# ## 1815.

# %% [markdown]
# ## 1816.

# %% [markdown]
# ## 1817.

# %% [markdown]
# ## 1818.

# %% [markdown]
# ## 1819.

# %% [markdown]
# ## 1820.

# %% [markdown]
# ## 1821.

# %% [markdown]
# ## 1822.

# %% [markdown]
# ## 1823.

# %% [markdown]
# ## 1824.

# %% [markdown]
# ## 1825.

# %% [markdown]
# ## 1826.

# %% [markdown]
# ## 1827.

# %% [markdown]
# ## 1828.

# %% [markdown]
# ## 1829.

# %% [markdown]
# ## 1830.

# %% [markdown]
# ## 1831.

# %% [markdown]
# ## 1832.

# %% [markdown]
# ## 1833.

# %% [markdown]
# ## 1834.

# %% [markdown]
# ## 1835.

# %% [markdown]
# ## 1836.

# %% [markdown]
# ## 1837.

# %% [markdown]
# ## 1838.

# %% [markdown]
# ## 1839.

# %% [markdown]
# ## 1840.

# %% [markdown]
# ## 1841.

# %% [markdown]
# ## 1842.

# %% [markdown]
# ## 1843.

# %% [markdown]
# ## 1844.

# %% [markdown]
# ## 1845.

# %% [markdown]
# ## 1846.

# %% [markdown]
# ## 1847.

# %% [markdown]
# ## 1848.

# %% [markdown]
# ## 1849.

# %% [markdown]
# ## 1850.

# %% [markdown]
# ## 1851.

# %% [markdown]
# ## 1852.

# %% [markdown]
# ## 1853.

# %% [markdown]
# ## 1854.

# %% [markdown]
# ## 1855.

# %% [markdown]
# ## 1856.

# %% [markdown]
# ## 1857.

# %% [markdown]
# ## 1858.

# %% [markdown]
# ## 1859.

# %% [markdown]
# ## 1860.

# %% [markdown]
# ## 1861.

# %% [markdown]
# ## 1862.

# %% [markdown]
# ## 1863.

# %% [markdown]
# ## 1864.

# %% [markdown]
# ## 1865.

# %% [markdown]
# ## 1866.

# %% [markdown]
# ## 1867.

# %% [markdown]
# ## 1868.

# %% [markdown]
# ## 1869.

# %% [markdown]
# ## 1870.

# %% [markdown]
# ## 1871.

# %% [markdown]
# ## 1872.

# %% [markdown]
# ## 1873.

# %% [markdown]
# ## 1874.

# %% [markdown]
# ## 1875.

# %% [markdown]
# ## 1876.

# %% [markdown]
# ## 1877.

# %% [markdown]
# ## 1878.

# %% [markdown]
# ## 1879.

# %% [markdown]
# ## 1880.

# %% [markdown]
# ## 1881.

# %% [markdown]
# ## 1882.

# %% [markdown]
# ## 1883.

# %% [markdown]
# ## 1884.

# %% [markdown]
# ## 1885.

# %% [markdown]
# ## 1886.

# %% [markdown]
# ## 1887.

# %% [markdown]
# ## 1888.

# %% [markdown]
# ## 1889.

# %% [markdown]
# ## 1890.

# %% [markdown]
# ## 1891.

# %% [markdown]
# ## 1892.

# %% [markdown]
# ## 1893.

# %% [markdown]
# ## 1894.

# %% [markdown]
# ## 1895.

# %% [markdown]
# ## 1896.

# %% [markdown]
# ## 1897.

# %% [markdown]
# ## 1898.

# %% [markdown]
# ## 1899.

# %% [markdown]
# ## 1900.

# %% [markdown]
# ## 1901.

# %% [markdown]
# ## 1902.

# %% [markdown]
# ## 1903.

# %% [markdown]
# ## 1904.

# %% [markdown]
# ## 1905.

# %% [markdown]
# ## 1906.

# %% [markdown]
# ## 1907.

# %% [markdown]
# ## 1908.

# %% [markdown]
# ## 1909.

# %% [markdown]
# ## 1910.

# %% [markdown]
# ## 1911.

# %% [markdown]
# ## 1912.

# %% [markdown]
# ## 1913.

# %% [markdown]
# ## 1914.

# %% [markdown]
# ## 1915.

# %% [markdown]
# ## 1916.

# %% [markdown]
# ## 1917.

# %% [markdown]
# ## 1918.

# %% [markdown]
# ## 1919.

# %% [markdown]
# ## 1920.

# %% [markdown]
# ## 1921.

# %% [markdown]
# ## 1922.

# %% [markdown]
# ## 1923.

# %% [markdown]
# ## 1924.

# %% [markdown]
# ## 1925.

# %% [markdown]
# ## 1926.

# %% [markdown]
# ## 1927.

# %% [markdown]
# ## 1928.

# %% [markdown]
# ## 1929.

# %% [markdown]
# ## 1930.

# %% [markdown]
# ## 1931.

# %% [markdown]
# ## 1932.

# %% [markdown]
# ## 1933.

# %% [markdown]
# ## 1934.

# %% [markdown]
# ## 1935.

# %% [markdown]
# ## 1936.

# %% [markdown]
# ## 1937.

# %% [markdown]
# ## 1938.

# %% [markdown]
# ## 1939.

# %% [markdown]
# ## 1940.

# %% [markdown]
# ## 1941.

# %% [markdown]
# ## 1942.

# %% [markdown]
# ## 1943.

# %% [markdown]
# ## 1944.

# %% [markdown]
# ## 1945.

# %% [markdown]
# ## 1946.

# %% [markdown]
# ## 1947.

# %% [markdown]
# ## 1948.

# %% [markdown]
# ## 1949.

# %% [markdown]
# ## 1950.

# %% [markdown]
# ## 1951.

# %% [markdown]
# ## 1952.

# %% [markdown]
# ## 1953.

# %% [markdown]
# ## 1954.

# %% [markdown]
# ## 1955.

# %% [markdown]
# ## 1956.

# %% [markdown]
# ## 1957.

# %% [markdown]
# ## 1958.

# %% [markdown]
# ## 1959.

# %% [markdown]
# ## 1960.

# %% [markdown]
# ## 1961.

# %% [markdown]
# ## 1962.

# %% [markdown]
# ## 1963.

# %% [markdown]
# ## 1964.

# %% [markdown]
# ## 1965.

# %% [markdown]
# ## 1966.

# %% [markdown]
# ## 1967.

# %% [markdown]
# ## 1968.

# %% [markdown]
# ## 1969.

# %% [markdown]
# ## 1970.

# %% [markdown]
# ## 1971.

# %% [markdown]
# ## 1972.

# %% [markdown]
# ## 1973.

# %% [markdown]
# ## 1974.

# %% [markdown]
# ## 1975.

# %% [markdown]
# ## 1976.

# %% [markdown]
# ## 1977.

# %% [markdown]
# ## 1978.

# %% [markdown]
# ## 1979.

# %% [markdown]
# ## 1980.

# %% [markdown]
# ## 1981.

# %% [markdown]
# ## 1982.

# %% [markdown]
# ## 1983.

# %% [markdown]
# ## 1984.

# %% [markdown]
# ## 1985.

# %% [markdown]
# ## 1986.

# %% [markdown]
# ## 1987.

# %% [markdown]
# ## 1988.

# %% [markdown]
# ## 1989.

# %% [markdown]
# ## 1990.

# %% [markdown]
# ## 1991.

# %% [markdown]
# ## 1992.

# %% [markdown]
# ## 1993.

# %% [markdown]
# ## 1994.

# %% [markdown]
# ## 1995.

# %% [markdown]
# ## 1996.

# %% [markdown]
# ## 1997.

# %% [markdown]
# ## 1998.

# %% [markdown]
# ## 1999.

# %% [markdown]
# ## 2000.
