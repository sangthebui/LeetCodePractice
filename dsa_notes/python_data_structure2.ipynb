# %% [markdown]
# # More useful python Data Structure and Algorithms

# %% [markdown]
# ## bisect

# %% [markdown]
# ### bisect

# %% [markdown]
# ### bisect_left

# %% [markdown]
# ### insort

# %% [markdown]
# ### insort_left

# %% [markdown]
# ### insort_right

# %% [markdown]
# ## defaultdict - safe dictionary

# %% [markdown]
# ### clear

# %% [markdown]
# ### copy

# %% [markdown]
# ### default_factory

# %% [markdown]
# ### fromkeys

# %% [markdown]
# ### get

# %% [markdown]
# ### items

# %% [markdown]
# ### keys

# %% [markdown]
# ### pop

# %% [markdown]
# ### popitem

# %% [markdown]
# ### setdefault

# %% [markdown]
# ### update

# %% [markdown]
# ### values
